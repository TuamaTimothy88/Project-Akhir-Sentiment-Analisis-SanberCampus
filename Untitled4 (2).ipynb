# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.6

# %% [markdown]
# <h2> Import Libary

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %% [markdown]
# <h2> Scraping Data

# %%
# scrap available review

from google_play_scraper import Sort, reviews

result, continuation_token  = reviews (
'com.gojek.app',
lang= 'id',
country= 'id',
sort= Sort.NEWEST,
count= 20000,
filter_score_with= None
)

# %%
df_gojek = pd.DataFrame(np.array(result),columns=['review'])

df_gojek = df_gojek.join(pd.DataFrame(df_gojek.pop('review').tolist()))

df_gojek.head()
# Out:
#                                reviewId              userName  \
# 0  20344ddb-1181-4417-9d22-84dc02396e79  Pijat sehat mm sindy
# 1  c5704de3-7139-4712-b45d-11f28f700b01                Ayu Sr
# 2  f4829d9f-95bc-4099-9e91-1730f07392fd          Dilla Almira
# 3  5e0e073c-680c-4c2b-9048-b48b0821cd69          Nur Solichin
# 4  62b6fd36-9d46-44cf-8e34-d7a1738be14f    aming Rivoallansah
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Sangat buruk,order yg jemput blum ada gopay ny...      1              0
# 1  Transportasi dan pesan makanan nya murah, bany...      5              0
# 2  Makin di update makin ga jelas. Ga bisa kirim ...      1              0
# 3                       Maps nya selalu salah tujuan      1              0
# 4  Pembayaran Pulsa Gagal Ada aktivitas Mencuriga...      1              0
#
#   reviewCreatedVersion                  at  \
# 0               4.82.1 2024-02-05 12:03:59
# 1                 None 2024-02-05 11:52:50
# 2               4.81.2 2024-02-05 11:46:50
# 3                 None 2024-02-05 11:45:54
# 4                 None 2024-02-05 11:41:23
#
#                                         replyContent           repliedAt  \
# 0  Hai Kak Sindy, mohon maaf atas ketidaknyamanan... 2024-02-05 14:36:12
# 1                                               None                 NaT
# 2  Hai Kak Dilla, mohon maaf atas ketidaknyamanan... 2024-02-05 12:41:57
# 3  Mohon maaf atas ketidaknyamanannya Kak. Sebelu... 2024-02-05 12:46:50
# 4  Hai Kak Aming, mohon maaf atas ketidaknyamanan... 2024-02-05 12:50:14
#
#   appVersion
# 0     4.82.1
# 1       None
# 2     4.81.2
# 3       None
# 4       None

# %%
df_gojek.tail()
# Out:
#                                    reviewId                  userName  \
# 19995  d85049c9-6cfa-4710-bfea-5ca9cf52f8cb              Andre Dinand
# 19996  4a87bafd-00cd-4e3d-9250-6772bada3a16              avian muslim
# 19997  c85c328e-2271-4804-85eb-178bd085f8ab            Andro Sulistio
# 19998  d8f193f9-5939-4651-a143-b644bc4fbc7f  Uswatun “Chubby” Hasanah
# 19999  cc860068-e9a4-489b-b354-13e649d1b8bd            Dedy Wijayanto
#
#                                                userImage  \
# 19995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 19996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 19998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 19995                                  Karya anak bangsa      5
# 19996                                             Mantap      5
# 19997                                               Good      5
# 19998  Lagi ada gangguan ap gimana siihhh sekarang ? ...      2
# 19999  Kenapa gopay later saya tidak bisa dipakai, pa...      1
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 19995              0                 None 2023-11-20 16:33:20
# 19996              0               4.78.3 2023-11-20 16:30:00
# 19997              0               4.74.3 2023-11-20 16:28:26
# 19998              0               4.78.3 2023-11-20 16:17:23
# 19999              0               4.78.3 2023-11-20 16:08:16
#
#                                             replyContent           repliedAt  \
# 19995                                               None                 NaT
# 19996                                               None                 NaT
# 19997                                               None                 NaT
# 19998  Hai Kak Uswatun, mohon maaf atas ketidaknyaman... 2023-11-21 00:34:03
# 19999  Hai Kak Dedy, mohon maaf atas ketidaknyamanan ... 2023-11-20 23:59:45
#
#       appVersion
# 19995       None
# 19996     4.78.3
# 19997     4.74.3
# 19998     4.78.3
# 19999     4.78.3

# %%
len(df_gojek.index)
# Out:
# 20000

# %%
data_new = df_gojek[['userName', 'score', 'at', 'content']]
data_new.head()
# Out:
#                userName  score                  at  \
# 0  Pijat sehat mm sindy      1 2024-02-05 12:03:59
# 1                Ayu Sr      5 2024-02-05 11:52:50
# 2          Dilla Almira      1 2024-02-05 11:46:50
# 3          Nur Solichin      1 2024-02-05 11:45:54
# 4    aming Rivoallansah      1 2024-02-05 11:41:23
#
#                                              content
# 0  Sangat buruk,order yg jemput blum ada gopay ny...
# 1  Transportasi dan pesan makanan nya murah, bany...
# 2  Makin di update makin ga jelas. Ga bisa kirim ...
# 3                       Maps nya selalu salah tujuan
# 4  Pembayaran Pulsa Gagal Ada aktivitas Mencuriga...

# %%
data_new = df_gojek[['userName', 'score', 'at', 'content']]
data_new.tail()
# Out:
#                        userName  score                  at  \
# 19995              Andre Dinand      5 2023-11-20 16:33:20
# 19996              avian muslim      5 2023-11-20 16:30:00
# 19997            Andro Sulistio      5 2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2 2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1 2023-11-20 16:08:16
#
#                                                  content
# 19995                                  Karya anak bangsa
# 19996                                             Mantap
# 19997                                               Good
# 19998  Lagi ada gangguan ap gimana siihhh sekarang ? ...
# 19999  Kenapa gopay later saya tidak bisa dipakai, pa...

# %%
#save data to folder
data_new.to_csv("datagojek.csv", index=False)

path = '\\Documents\\Analisis Sentimen Gojek\\Data File\\'

# %% [markdown]
# <h1> Preprocessing
#
# **Loading Data Frame**

# %%
df = pd.read_csv("datagojek.csv")


df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content
# 0      Sangat buruk,order yg jemput blum ada gopay ny...
# 1      Transportasi dan pesan makanan nya murah, bany...
# 2      Makin di update makin ga jelas. Ga bisa kirim ...
# 3                           Maps nya selalu salah tujuan
# 4      Pembayaran Pulsa Gagal Ada aktivitas Mencuriga...
# ...                                                  ...
# 19995                                  Karya anak bangsa
# 19996                                             Mantap
# 19997                                               Good
# 19998  Lagi ada gangguan ap gimana siihhh sekarang ? ...
# 19999  Kenapa gopay later saya tidak bisa dipakai, pa...
#
# [20000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   userName  20000 non-null  object
#  1   score     20000 non-null  int64
#  2   at        20000 non-null  object
#  3   content   20000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 625.1+ KB

# %%
df = df.drop(df.loc[df['score'] == 3].index)
df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content
# 0      Sangat buruk,order yg jemput blum ada gopay ny...
# 1      Transportasi dan pesan makanan nya murah, bany...
# 2      Makin di update makin ga jelas. Ga bisa kirim ...
# 3                           Maps nya selalu salah tujuan
# 4      Pembayaran Pulsa Gagal Ada aktivitas Mencuriga...
# ...                                                  ...
# 19995                                  Karya anak bangsa
# 19996                                             Mantap
# 19997                                               Good
# 19998  Lagi ada gangguan ap gimana siihhh sekarang ? ...
# 19999  Kenapa gopay later saya tidak bisa dipakai, pa...
#
# [19094 rows x 4 columns]

# %% [markdown]
# <h1> Labelling Data

# %%
def pelabelan(rate):
    if rate <= 2 :
        return 'negatif'
    else:
        return 'positif'

df['label'] = df['score'].apply(pelabelan)
df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label
# 0      Sangat buruk,order yg jemput blum ada gopay ny...  negatif
# 1      Transportasi dan pesan makanan nya murah, bany...  positif
# 2      Makin di update makin ga jelas. Ga bisa kirim ...  negatif
# 3                           Maps nya selalu salah tujuan  negatif
# 4      Pembayaran Pulsa Gagal Ada aktivitas Mencuriga...  negatif
# ...                                                  ...      ...
# 19995                                  Karya anak bangsa  positif
# 19996                                             Mantap  positif
# 19997                                               Good  positif
# 19998  Lagi ada gangguan ap gimana siihhh sekarang ? ...  negatif
# 19999  Kenapa gopay later saya tidak bisa dipakai, pa...  negatif
#
# [19094 rows x 5 columns]

# %% [markdown]
# <h1>Preprocessing

# %%
import nltk

# %%
# mengubah data pada column content menjadi string agar dapat melakukan pemrosesan data teks
df['content'] = df['content'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19094 entries, 0 to 19999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   userName  19094 non-null  object
#  1   score     19094 non-null  int64
#  2   at        19094 non-null  object
#  3   content   19094 non-null  object
#  4   label     19094 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 895.0+ KB

# %% [markdown]
# <h1> Cleansing

# %%
import re
import string

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")

df['content'] = df['content'].apply(remove_links)

#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

df['content'] = df['content'].apply(remove_number)

#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['content'] = df['content'].apply(remove_punctuation)

# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

df['content'] = df['content'].apply(remove_singl_char)

# menghapus number how to fix it
def remove_number(text):
    return re.sub(r"\d+", " ", text)

df['content'] = df['content'].apply(remove_number)

# %%
df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label
# 0      Sangat burukorder yg jemput blum ada gopay nya...  negatif
# 1      Transportasi dan pesan makanan nya murah banya...  positif
# 2      Makin di update makin ga jelas Ga bisa kirim f...  negatif
# 3                           Maps nya selalu salah tujuan  negatif
# 4      Pembayaran Pulsa Gagal Ada aktivitas Mencuriga...  negatif
# ...                                                  ...      ...
# 19995                                  Karya anak bangsa  positif
# 19996                                             Mantap  positif
# 19997                                               Good  positif
# 19998  Lagi ada gangguan ap gimana siihhh sekarang  P...  negatif
# 19999  Kenapa gopay later saya tidak bisa dipakai pad...  negatif
#
# [19094 rows x 5 columns]

# %% [markdown]
# <h1> Case Folding

# %%
df['content'] = df['content'].str.lower()

df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label
# 0      sangat burukorder yg jemput blum ada gopay nya...  negatif
# 1      transportasi dan pesan makanan nya murah banya...  positif
# 2      makin di update makin ga jelas ga bisa kirim f...  negatif
# 3                           maps nya selalu salah tujuan  negatif
# 4      pembayaran pulsa gagal ada aktivitas mencuriga...  negatif
# ...                                                  ...      ...
# 19995                                  karya anak bangsa  positif
# 19996                                             mantap  positif
# 19997                                               good  positif
# 19998  lagi ada gangguan ap gimana siihhh sekarang  p...  negatif
# 19999  kenapa gopay later saya tidak bisa dipakai pad...  negatif
#
# [19094 rows x 5 columns]

# %% [markdown]
# <h1> Tokenize

# %%
import string
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['content_tokenize'] = df['content'].apply(word_tokenize_wrapper)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label  \
# 0      sangat burukorder yg jemput blum ada gopay nya...  negatif
# 1      transportasi dan pesan makanan nya murah banya...  positif
# 2      makin di update makin ga jelas ga bisa kirim f...  negatif
# 3                           maps nya selalu salah tujuan  negatif
# 4      pembayaran pulsa gagal ada aktivitas mencuriga...  negatif
# ...                                                  ...      ...
# 19995                                  karya anak bangsa  positif
# 19996                                             mantap  positif
# 19997                                               good  positif
# 19998  lagi ada gangguan ap gimana siihhh sekarang  p...  negatif
# 19999  kenapa gopay later saya tidak bisa dipakai pad...  negatif
#
#                                         content_tokenize
# 0      [sangat, burukorder, yg, jemput, blum, ada, go...
# 1      [transportasi, dan, pesan, makanan, nya, murah...
# 2      [makin, di, update, makin, ga, jelas, ga, bisa...
# 3                     [maps, nya, selalu, salah, tujuan]
# 4      [pembayaran, pulsa, gagal, ada, aktivitas, men...
# ...                                                  ...
# 19995                              [karya, anak, bangsa]
# 19996                                           [mantap]
# 19997                                             [good]
# 19998  [lagi, ada, gangguan, ap, gimana, siihhh, seka...
# 19999  [kenapa, gopay, later, saya, tidak, bisa, dipa...
#
# [19094 rows x 6 columns]

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

content_fqsist = df['content_tokenize'].apply(freqDist_wrapper)

print('Frequency Tokens : \n')
print(content_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(sangat, 1), (burukorder, 1), (yg, 1), (jempu...
# 1    [(dan, 2), (nya, 2), (diskon, 2), (transportas...
# 2    [(makin, 2), (ga, 2), (foto, 2), (di, 1), (upd...
# 3    [(maps, 1), (nya, 1), (selalu, 1), (salah, 1),...
# 4    [(pulsa, 2), (di, 2), (saya, 2), (tidak, 2), (...
# Name: content_tokenize, dtype: object

# %% [markdown]
# <h1> Normalisasi

# %%
slank_word_dict = {

    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_table("https://raw.githubusercontent.com/evrintobing17/NormalisasiKata/master/kbba.txt")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("https://raw.githubusercontent.com/IndianiTiosari01/Proyek-KuliahPM-NormalisasiKata/master/kamus_alay.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
df['content_normalized'] = df['content_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label  \
# 0      sangat burukorder yg jemput blum ada gopay nya...  negatif
# 1      transportasi dan pesan makanan nya murah banya...  positif
# 2      makin di update makin ga jelas ga bisa kirim f...  negatif
# 3                           maps nya selalu salah tujuan  negatif
# 4      pembayaran pulsa gagal ada aktivitas mencuriga...  negatif
# ...                                                  ...      ...
# 19995                                  karya anak bangsa  positif
# 19996                                             mantap  positif
# 19997                                               good  positif
# 19998  lagi ada gangguan ap gimana siihhh sekarang  p...  negatif
# 19999  kenapa gopay later saya tidak bisa dipakai pad...  negatif
#
#                                         content_tokenize  \
# 0      [sangat, burukorder, yg, jemput, blum, ada, go...
# 1      [transportasi, dan, pesan, makanan, nya, murah...
# 2      [makin, di, update, makin, ga, jelas, ga, bisa...
# 3                     [maps, nya, selalu, salah, tujuan]
# 4      [pembayaran, pulsa, gagal, ada, aktivitas, men...
# ...                                                  ...
# 19995                              [karya, anak, bangsa]
# 19996                                           [mantap]
# 19997                                             [good]
# 19998  [lagi, ada, gangguan, ap, gimana, siihhh, seka...
# 19999  [kenapa, gopay, later, saya, tidak, bisa, dipa...
#
#                                       content_normalized
# 0      [sangat, burukorder, yang, jemput, belum, ada,...
# 1      [transportasi, dan, pesan, makanan, nya, murah...
# 2      [makin, di, update, makin, enggak, jelas, engg...
# 3                     [maps, nya, selalu, salah, tujuan]
# 4      [pembayaran, pulsa, gagal, ada, aktivitas, men...
# ...                                                  ...
# 19995                              [karya, anak, bangsa]
# 19996                                           [mantap]
# 19997                                             [good]
# 19998  [lagi, ada, gangguan, apa, bagaimana, sih, sek...
# 19999  [kenapa, gopay, later, saya, tidak, bisa, dipa...
#
# [19094 rows x 7 columns]

# %% [markdown]
# <h1> Stopword Removal

# %%
from nltk.corpus import stopwords

# %%
import string
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')

nltk.download('stopwords')

list_stopwords = stopwords.words('indonesian')

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['content_tokenize'] = df['content'].apply(word_tokenize_wrapper)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['content_stop_removed'] = df['content_normalized'].apply(stopwords_removal)

# %%
df
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19995              Andre Dinand      5  2023-11-20 16:33:20
# 19996              avian muslim      5  2023-11-20 16:30:00
# 19997            Andro Sulistio      5  2023-11-20 16:28:26
# 19998  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19999            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label  \
# 0      sangat burukorder yg jemput blum ada gopay nya...  negatif
# 1      transportasi dan pesan makanan nya murah banya...  positif
# 2      makin di update makin ga jelas ga bisa kirim f...  negatif
# 3                           maps nya selalu salah tujuan  negatif
# 4      pembayaran pulsa gagal ada aktivitas mencuriga...  negatif
# ...                                                  ...      ...
# 19995                                  karya anak bangsa  positif
# 19996                                             mantap  positif
# 19997                                               good  positif
# 19998  lagi ada gangguan ap gimana siihhh sekarang  p...  negatif
# 19999  kenapa gopay later saya tidak bisa dipakai pad...  negatif
#
#                                         content_tokenize  \
# 0      [sangat, burukorder, yg, jemput, blum, ada, go...
# 1      [transportasi, dan, pesan, makanan, nya, murah...
# 2      [makin, di, update, makin, ga, jelas, ga, bisa...
# 3                     [maps, nya, selalu, salah, tujuan]
# 4      [pembayaran, pulsa, gagal, ada, aktivitas, men...
# ...                                                  ...
# 19995                              [karya, anak, bangsa]
# 19996                                           [mantap]
# 19997                                             [good]
# 19998  [lagi, ada, gangguan, ap, gimana, siihhh, seka...
# 19999  [kenapa, gopay, later, saya, tidak, bisa, dipa...
#
#                                       content_normalized  \
# 0      [sangat, burukorder, yang, jemput, belum, ada,...
# 1      [transportasi, dan, pesan, makanan, nya, murah...
# 2      [makin, di, update, makin, enggak, jelas, engg...
# 3                     [maps, nya, selalu, salah, tujuan]
# 4      [pembayaran, pulsa, gagal, ada, aktivitas, men...
# ...                                                  ...
# 19995                              [karya, anak, bangsa]
# 19996                                           [mantap]
# 19997                                             [good]
# 19998  [lagi, ada, gangguan, apa, bagaimana, sih, sek...
# 19999  [kenapa, gopay, later, saya, tidak, bisa, dipa...
#
#                                     content_stop_removed
# 0               [burukorder, jemput, gopay, nya, hilang]
# 1      [transportasi, pesan, makanan, nya, murah, dis...
# 2      [update, kirim, foto, driver, galeri, ribet, f...
# 3                             [maps, nya, salah, tujuan]
# 4      [pembayaran, pulsa, gagal, aktivitas, mencurig...
# ...                                                  ...
# 19995                              [karya, anak, bangsa]
# 19996                                           [mantap]
# 19997                                             [good]
# 19998            [gangguan, sih, pas, upgred, nihkecewa]
# 19999  [gopay, later, dipakai, diandalkan, terang, pe...
#
# [19094 rows x 8 columns]

# %% [markdown]
# <h1> Stemming

# %%
pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2023.8.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.66.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (7.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (1.23.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16506 sha256=ff8df93858383e2e64291595c724b2e04454f62f2a7a154e61036e9816b08a10
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# Installing collected packages: swifter
# Successfully installed swifter-1.4.0

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['content_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['content_Stemmed'] = df['content_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# mnjadikan : mnjadikan
# tlf : tlf
# promodiskon : promodiskon
# diskonpromo : diskonpromo
# walopun : walopun
# mangaaap : mangaaap
# gembelerror : gembelerror
# terusdelete : terusdelete
# sajalahhh : sajalahhh
# pelunasan : lunas
# mantaaapppp : mantaaapppp
# dahlah : dah
# mlipir : mlipir
# sebelahh : sebelahh
# joossssssssss : joossssssssss
# terrrrrrrrbaik : terrrrrrrrbaik
# mengoperasikan : operasi
# izza : izza
# okj : okj
# sayamohon : sayamohon
# goridenya : goridenya
# driverterima : driverterima
# gojeksukses : gojeksukses
# kesopanan : sopan
# murahbanyak : murahbanyak
# abdet : abdet
# seditealnya : seditealnya
# ksnimakin : ksnimakin
# ty : ty
# uinstal : uinstal
# hand : hand
# cokk : cokk
# gmpang : gmpang
# jauhgiliran : jauhgiliran
# barutambah : barutambah
# kontoll : kontoll
# anjeeng : anjeeng
# thankssejauh : thankssejauh
# oksangat : oksangat
# kawak : kawak
# lancarlancar : lancarlancar
# butu : butu
# beruubah : beruubah
# anjeeengg : anjeeengg
# gapernha : gapernha
# sampahhh : sampahhh
# masalhnya : masalhnya
# check : check
# parahhhhhhhh : parahhhhhhhh
# tujuanfiturnya : tujuanfiturnya
# pemula : mula
# kendaraannyakalo : kendaraannyakalo
# padahluda : padahluda
# wife : wife
# dislike : dislike
# benr : benr
# mentalnya : mental
# udahnya : udahnya
# boomerang : boomerang
# dimata : mata
# memuat : muat
# goridecar : goridecar
# langkah : langkah
# something : something
# takkan : tak
# terganti : ganti
# kenapakok : kenapakok
# diacceptpadahal : diacceptpadahal
# weysaya : weysaya
# bumil : bumil
# gocargamau : gocargamau
# mengantarkahpadahal : mengantarkahpadahal
# awokwok : awokwok
# pengendara : kendara
# jongos : jongos
# sen : sen
# gaaba : gaaba
# kutabrak : tabrak
# gilas : gilas
# kepalanyaorg : kepalanyaorg
# jijik : jijik
# tingkahnya : tingkah
# anjengoknum : anjengoknum
# anjengotaknya : anjengotaknya
# labil : labil
# jugamantap : jugamantap
# bangetttty : bangetttty
# dulupesen : dulupesen
# sejahterakan : sejahtera
# diperbaik : baik
# laatter : laatter
# bgtzb : bgtzb
# tmksh : tmksh
# umroh : umroh
# menyenang : senang
# canggu : canggu
# fropaider : fropaider
# tiadak : tiadak
# goshopmmm : goshopmmm
# ribetin : ribetin
# memepcepat : memepcepat
# benerbener : benerbener
# mendang : dang
# mendingsnoga : mendingsnoga
# buan : buan
# permainannya : main
# dibisa : bisa
# lanjutan : lanjut
# aksi : aksi
# demo : demo
# backup : backup
# registrasi : registrasi
# mentransferkan : transfer
# merek : merek
# dilempar : lempar
# sera : sera
# zoo : zoo
# world : world
# tjuanbiarpun : tjuanbiarpun
# kebablas : bablas
# berulah : ulah
# dengn : dengn
# pki : pki
# bawel : bawel
# mintanya : minta
# jossszzzz : jossszzzz
# giat : giat
# duduk : duduk
# berhemat : hemat
# kendaraannya : kendara
# berkedok : kedok
# divisi : divisi
# semestinya : mesti
# pnjam : pnjam
# tokopediaada : tokopediaada
# minemang : memang
# transaksinomor : transaksinomor
# mengapus : mengapus
# ditawarkan : tawar
# multifungsii : multifungsi
# bannget : bannget
# awak : awak
# manjang : manjang
# pilat : pilat
# martabaknya : martabak
# ngbugs : ngbugs
# obokobok : obokobok
# utakatik : utakatik
# mengerim : rim
# bagustop : bagustop
# perjalananku : jalan
# aplikasinyalayanan : aplikasinyalayanan
# ambildan : ambildan
# ngawurrrrr : ngawurrrrr
# pengirim : kirim
# pengaturannya : atur
# ajakecewa : ajakecewa
# koperatif : koperatif
# blokirduh : blokirduh
# andelin : andelin
# tpsekarang : tpsekarang
# aolikasi : aolikasi
# payahgabisa : payahgabisa
# minuss : minuss
# minkok : minkok
# donlop : donlop
# eazu : eazu
# ganguan : ganguan
# berani : berani
# pakenya : pakenya
# awam : awam
# kebalikan : balik
# terusin : terusin
# hayo : hayo
# sahammu : saham
# pesat : pesat
# ding : ding
# ajjj : ajjj
# layan : layan
# sayah : sayah
# semuah : semuah
# pokonamah : pokonamah
# sabtu : sabtu
# nasional : nasional
# tokopediaaneh : tokopediaaneh
# tinggalnya : tinggal
# kaitannya : kait
# nunguin : nunguin
# membuahkan : buah
# syukaaa : syukaaa
# seblumnya : seblumnya
# konter : konter
# ll : ll
# nyakalo : nyakalo
# donkdipesan : donkdipesan
# dititik : titik
# dkat : dkat
# kecawa : kecawa
# indriver : indriver
# mbangkin : mbangkin
# virtualaqun : virtualaqun
# bergunakecewa : bergunakecewa
# anjirrrrbalikin : anjirrrrbalikin
# pokokny : pokokny
# amplikasi : amplikasi
# kga : kga
# petunjuk : tunjuk
# rilis : rilis
# boslimit : boslimit
# fulltidak : fulltidak
# membuktikannymn : membuktikannymn
# besarbesaran : besarbesaran
# lagiinimah : lagiinimah
# limitnyaktnya : limitnyaktnya
# bugini : bugini
# timedit : timedit
# yahtp : yahtp
# solusidr : solusidr
# dekatlapar : dekatlapar
# kenyangkarna : kenyangkarna
# sikit : sikit
# pokokoe : pokokoe
# puenak : puenak
# lagilah : lagi
# doublean : doublean
# burusaya : burusaya
# jado : jado
# operasional : operasional
# protes : protes
# lebihkan : lebih
# sontoloyo : sontoloyo
# matab : matab
# sayas : sayas
# tertolong : tolong
# gosendpengiriman : gosendpengiriman
# aela : aela
# diemail : email
# penjemputanmending : penjemputanmending
# bangetbanyak : bangetbanyak
# gejek : gejek
# kembalikeluar : kembalikeluar
# sendirikenapa : sendirikenapa
# drepernya : drepernya
# drepermu : drepermu
# cakap : cakap
# pem : pem
# menafkahi : nafkah
# onlein : onlein
# kaklo : kaklo
# lebihin : lebihin
# inu : inu
# mejelang : mejelang
# rh : rh
# paksyarat : paksyarat
# bukankan : bukan
# diarternatipmasuk : diarternatipmasuk
# karntor : karntor
# pulusi : pulusi
# bekel : bekel
# sembuh : sembuh
# sata : sata
# sepiker : sepiker
# hali : hal
# aternatip : aternatip
# menyembuhkan : sembuh
# tubuhku : tubuh
# rulis : rulis
# mentoro : toro
# pansmdai : pansmdai
# jatung : jatung
# terapi : terapi
# dibekam : bekam
# tujuanjujur : tujuanjujur
# dansopan : dansopan
# bertaun : taun
# goridegocargofood : goridegocargofood
# tolakalasanya : tolakalasanya
# lahir : lahir
# gocartp : gocartp
# penjelasancoba : penjelasancoba
# gopaytransaksi : gopaytransaksi
# seringtp : seringtp
# pinjeman : pinjeman
# diac : diac
# caahback : caahback
# iyanunggunya : iyanunggunya
# whell : whell
# everythimg : everythimg
# mantabss : mantabss
# mknan : mknan
# epada : epada
# peraturan : atur
# teridentifikasi : identifikasi
# loohhhhhh : loohhhhhh
# intuk : intuk
# memakan : makan
# resources : resources
# sesalu : sesalu
# menjauh : jauh
# kedrever : kedrever
# terimanya : terima
# seberapaapalagi : seberapaapalagi
# ordermisal : ordermisal
# custamer : custamer
# ceo : ceo
# catherin : catherin
# sejammau : sejammau
# pelanggaran : langgar
# diharuskan : harus
# selang : selang
# crk : crk
# rsradjak : rsradjak
# pungsi : pungsi
# pbayaran : pbayaran
# warga : warga
# basmalah : basmalah
# yol : yol
# terjebak : jebak
# maudi : maudi
# lumasin : lumasin
# takutkan : takut
# umur : umur
# teruslah : terus
# tumbuh : tumbuh
# persaingan : saing
# natal : natal
# ckckckck : ckckckck
# oencengnya : oencengnya
# toplahhh : toplahhh
# caray : caray
# sdangkan : sdangkan
# hpy : hpy
# gojeksemua : gojeksemua
# cod : cod
# butuhinada : butuhinada
# memaklumi : maklum
# kerena : rena
# internal : internal
# pesa : pesa
# parahpesan : parahpesan
# lamakarena : lamakarena
# kejepit : jepit
# diberlakukan : laku
# penyesuaian : sesuai
# utamaaku : utamaaku
# nyaayang : nyaayang
# murahan : murah
# kelakuannya : laku
# pelatihan : latih
# goclean : goclean
# kembalibutuh : kembalibutuh
# bebersih : bersih
# rusakorder : rusakorder
# dibikinin : dibikinin
# kirimorder : kirimorder
# sebiji : biji
# lebihngotak : lebihngotak
# canceleh : canceleh
# lipatpantas : lipatpantas
# mainnya : main
# dicari : cari
# siaphampir : siaphampir
# kelparan : kelparan
# kcewakan : kcewakan
# ibadah : ibadah
# kwalitas : kwalitas
# gerimissusah : gerimissusah
# sekalimencari : sekalimencari
# merahapakah : merahapakah
# driverketika : driverketika
# lappetttt : lappetttt
# haus : haus
# pertahanin : pertahanin
# prihatin : prihatin
# ngliat : ngliat
# curhatan : curhatan
# ina : ina
# anying : anying
# dongon : dongon
# ribetwalau : ribetwalau
# sldo : sldo
# amanmkassih : amanmkassih
# nemudahkan : nemudahkan
# perbelanjaan : belanja
# apiklah : apik
# goprem : goprem
# berima : rima
# ooppsss : ooppsss
# suruhh : suruhh
# gimanaaa : gimanaaa
# matappp : matappp
# tooooop : tooooop
# teu : teu
# bere : bere
# aing : aing
# badot : badot
# okeeh : okeeh
# bangeddbonus : bangeddbonus
# buanyakmksh : buanyakmksh
# ngawi : ngawi
# kapasitas : kapasitas
# lamasaya : lamasaya
# kebusukan : busuk
# susahhhh : susahhhh
# pinginnya : pinginnya
# barangsalah : barangsalah
# trlambat : trlambat
# basisdh : basisdh
# akhirny : akhirny
# diselesaikan : selesai
# makananx : makananx
# pacet : pacet
# mojokerto : mojokerto
# nakalsdh : nakalsdh
# matikankatanya : matikankatanya
# gededia : gededia
# kelebihan : lebih
# driverx : driverx
# piriksi : piriksi
# jiringin : jiringin
# intirnitnyi : intirnitnyi
# dili : dil
# yi : yi
# discon : discon
# cairin : cairin
# berjalannya : jalan
# berubaaaaaaaaah : berubaaaaaaaaah
# lodingnya : lodingnya
# chatan : chatan
# terbodoh : bodoh
# spamudah : spamudah
# ngenganggu : ngenganggu
# enggalagi : enggalagi
# ngzoom : ngzoom
# iklantolong : iklantolong
# ngenggu : ngenggu
# tokpednya : tokpednya
# lemottr : lemottr
# akibatnya : akibat
# berturutturut : berturutturut
# kuantitasnya : kuantitas
# sampahgopaypaylater : sampahgopaypaylater
# dipakegopaypinjam : dipakegopaypinjam
# minjemin : minjemin
# semuamari : semuamari
# electrik : electrik
# polusi : polusi
# udara : udara
# berisik : berisik
# kojadi : kojadi
# nal : nal
# confirmasi : confirmasi
# edy : edy
# sihcuma : sihcuma
# gopaylatertgl : gopaylatertgl
# lunastapi : lunastapi
# lagidicoba : lagidicoba
# besoknya : besok
# samapilihan : samapilihan
# alangkah : alangkah
# endingnya : endingnya
# respond : respond
# bilnya : bilnya
# trnportasi : trnportasi
# selebihny : selebihny
# enggk : enggk
# pembicaraan : bicara
# dalih : dalih
# prilaku : prilaku
# kesajhteraan : kesajhteraan
# separuh : paruh
# sepadan : padan
# perusahaanmu : usaha
# disemua : semua
# tepaksa : tepaksa
# matuull : matuull
# qmwmana : qmwmana
# yagembel : yagembel
# bngetklo : bngetklo
# umpetin : umpetin
# lahd : lahd
# sihmasa : sihmasa
# services : services
# excellence : excellence
# menanggung : tanggung
# apaansih : apaansih
# palah : palah
# dimananya : mana
# eeeee : eeeee
# updatepayah : updatepayah
# tibe : tibe
# sedikittapi : sedikittapi
# dibukanya : buka
# yyah : yyah
# adaain : adaain
# tul : tul
# gaaman : gaaman
# datng : datng
# tetanggaku : tetangga
# nambahin : nambahin
# harifreak : harifreak
# bgtbiasa : bgtbiasa
# cashini : cashini
# payments : payments
# burukpesan : burukpesan
# sudi : sudi
# datangkami : datangkami
# sewa : sewa
# kleanbayar : kleanbayar
# sewenang : wenang
# wenangtk : wenangtk
# sewaburuk : sewaburuk
# niiterutama : niiterutama
# kabupaten : kabupaten
# sragencam : sragencam
# anjinggghhh : anjinggghhh
# keracunan : racun
# superr : superr
# berantem : antem
# mamtapz : mamtapz
# baus : baus
# lagimending : lagimending
# mentanng : mentanng
# suwe : suwe
# cpk : cpk
# dibuatny : dibuatny
# digabungin : digabungin
# batasi : batas
# downdload : downdload
# berpungsi : pungsi
# popo : popo
# jugayang : jugayang
# iklasiang : iklasiang
# rini : rini
# senam : senam
# dorong : dorong
# awas : awas
# vouchermakin : vouchermakin
# panas : panas
# telesat : telesat
# setthanks : setthanks
# dikenakandan : dikenakandan
# driverbiaya : driverbiaya
# dianjurkan : anjur
# diajar : ajar
# berhutang : hutang
# sjdianjurkan : sjdianjurkan
# creditgopay : creditgopay
# gitugopay : gitugopay
# makarimbener : makarimbener
# jelaas : jelaas
# armadanya : armada
# pengerjaan : kerja
# pelebaran : lebar
# jempol : jempol
# mengomongnya : omong
# promomya : promomya
# qaaaa : qaaaa
# aa : aa
# gaaaspooool : gaaaspooool
# fiturr : fiturr
# taheeed : taheeed
# jnl : jnl
# dimohon : mohon
# harikalau : harikalau
# inmalah : inmalah
# nulisny : nulisny
# ojekny : ojekny
# mengecewakanaplikasinya : mengecewakanaplikasinya
# zolim : zolim
# penjajah : jajah
# injak : injak
# tbk : tbk
# puassss : puassss
# ketiduran : tidur
# kesrharian : kesrharian
# sayatrimakasih : sayatrimakasih
# way : way
# ver : ver
# op : op
# ditotal : total
# wisely : wisely
# smart : smart
# decision : decision
# aplikasilah : aplikasi
# jijay : jijay
# bajay : bajay
# brgnya : brgnya
# tma : tma
# agya : agya
# menjauhi : jauh
# sambilan : sambil
# tarifmu : tarif
# galang : galang
# sumut : sumut
# ffl : ffl
# nelfon : nelfon
# waitingnya : waitingnya
# keangkat : angkat
# penasaran : penasaran
# naudzubillah : naudzubillah
# nasabahmu : nasabah
# menux : menux
# lohini : lohini
# aplikasixtlg : aplikasixtlg
# sayabiar : sayabiar
# daoat : daoat
# bekukandi : bekukandi
# gunakanbye : gunakanbye
# kotak : kotak
# limittp : limittp
# sendiritolong : sendiritolong
# mudahtetapi : mudahtetapi
# pengurangan : kurang
# finalty : finalty
# pembtalan : pembtalan
# heuuhh : heuuhh
# terbatlkan : terbatlkan
# perluperlu : perluperlu
# ngehang : ngehang
# tiktok : tiktok
# tang : tang
# usercustomer : usercustomer
# almost : almost
# with : with
# fvckk : fvckk
# shock : shock
# bantuinnnn : bantuinnnn
# ngehangngehang : ngehangngehang
# beku : beku
# digerakin : digerakin
# expert : expert
# disamain : disamain
# blmd : blmd
# plabuhan : plabuhan
# tgpriok : tgpriok
# bnar : bnar
# notife : notife
# transction : transction
# failed : failed
# kesibukan : sibuk
# batelin : batelin
# jangkauannya : jangkau
# merk : merk
# godjoob : godjoob
# pnjmputan : pnjmputan
# nunggumsak : nunggumsak
# stgah : stgah
# jamini : jamin
# dprhatikan : dprhatikan
# kecewadg : kecewadg
# ngedrop : ngedrop
# dtrima : dtrima
# liked : liked
# mie : mie
# lembek : lembek
# cacing : cacing
# terbantuselalu : terbantuselalu
# mudahmudahan : mudahmudahan
# wisata : wisata
# auuuuu : auuuuu
# druver : druver
# lancarkenapa : lancarkenapa
# kancel : kancel
# perhitungan : hitung
# cepetpaling : cepetpaling
# akuratpaling : akuratpaling
# dakhori : dakhori
# tamunya : tamu
# gojekgojek : gojekgojek
# ngemisjadi : ngemisjadi
# keselalesannya : keselalesannya
# kgua : kgua
# luharusnya : luharusnya
# syukuri : syukur
# ngeolngemis : ngeolngemis
# ulangi : ulang
# dehk : dehk
# krg : krg
# gojekgak : gojekgak
# mahaltapi : mahaltapi
# sendir : sendir
# keundur : undur
# mancap : mancap
# inipesan : inipesan
# gabungannunggu : gabungannunggu
# laama : laama
# jekudah : jekudah
# normalterlalu : normalterlalu
# aplikatorjangan : aplikatorjangan
# oyyg : oyyg
# berjuang : juang
# dilapangan : lapang
# mulia : mulia
# officekalo : officekalo
# gajih : gajih
# tercinta : cinta
# perbanyaklah : banyak
# jf : jf
# promotor : promotor
# launching : launching
# mengantarr : mengantarr
# nopolnya : nopolnya
# nyacari : nyacari
# sulitnya : sulit
# bbmkadang : bbmkadang
# maudah : maudah
# mahalluar : mahalluar
# wesmending : wesmending
# memudahkangak : memudahkangak
# menucukup : menucukup
# gofoodgoridedan : gofoodgoridedan
# pemantauanaplikasi : pemantauanaplikasi
# modelan : model
# cimb : cimb
# kasihani : kasihan
# nyerah : nyerah
# asuh : asuh
# ngordernya : ngordernya
# leguler : leguler
# cancelin : cancelin
# kewl : kewl
# paai : paai
# initp : initp
# erorwaktu : erorwaktu
# bisamalah : bisamalah
# accuont : accuont
# kadaluwarsa : kadaluwarsa
# menyalahi : salah
# bities : bities
# collab : collab
# really : really
# berhak : hak
# cuanya : cua
# cekek : cekek
# kendalakonsumen : kendalakonsumen
# oranh : oranh
# pakaisistem : pakaisistem
# claus : claus
# tingkatkatkan : tingkatkatkan
# dlsaya : dlsaya
# menyuruh : suruh
# sarapan : sarap
# jidasnya : jidasnya
# ditegur : tegur
# jelekmau : jelekmau
# gopinmau : gopinmau
# bisaanjong : bisaanjong
# sukakkkk : sukakkkk
# pendapatannyasudah : pendapatannyasudah
# profeder : profeder
# mainan : main
# sekor : kor
# dibunuh : bunuh
# pelan : pelan
# pelayananpendapatan : pelayananpendapatan
# dipangkas : pangkas
# dibodoh : bodoh
# dipindah : pindah
# pendekbiar : pendekbiar
# untungoperator : untungoperator
# emas : emas
# sepesial : sial
# goggle : goggle
# syudahlah : syudahlah
# kebijakannya : bijak
# bayarpercuma : bayarpercuma
# tolongggg : tolongggg
# seppp : seppp
# cache : cache
# dikosongininternetpun : dikosongininternetpun
# pegawainya : pegawai
# muda : muda
# ipk : ipk
# apkx : apkx
# dlux : dlux
# siiipppp : siiipppp
# bangetharus : bangetharus
# disangsi : sangsi
# alfagift : alfagift
# bima : bima
# pascabayar : pascabayar
# gajelass : gajelass
# makananminuman : makananminuman
# sskali : sskali
# lngsng : lngsng
# lemotttttt : lemotttttt
# bersangkutan : sangkut
# buktinyatp : buktinyatp
# bersangkutanmohon : bersangkutanmohon
# kekeliruantruss : kekeliruantruss
# ojektp : ojektp
# mahaldan : mahaldan
# romusha : romusha
# gaptek : gaptek
# parh : parh
# mendesk : mendesk
# paraaaaahhhlahh : paraaaaahhhlahh
# bangetmurah : bangetmurah
# telatlimit : telatlimit
# teruspas : teruspas
# alesannya : alesannya
# sibukpercuma : sibukpercuma
# custmer : custmer
# ngt : ngt
# copy : copy
# paste : paste
# custemer : custemer
# membatalkn : membatalkn
# siihhhhhh : siihhhhhh
# bugh : bugh
# menyolot : solot
# ngomel : ngomel
# kendalaasyik : kendalaasyik
# masukkin : masukkin
# angka : angka
# kepencetsaat : kepencetsaat
# buy : buy
# terkonfirmasi : konfirmasi
# dibedakan : beda
# lgtidak : lgtidak
# mahaaaaaaaal : mahaaaaaaaal
# infomasi : infomasi
# informatif : informatif
# bangetsaya : bangetsaya
# sendiriudah : sendiriudah
# salahgunakangw : salahgunakangw
# tuntut : tuntut
# gojekgw : gojekgw
# sekarangg : sekarangg
# done : done
# skalikesaldibuka : skalikesaldibuka
# tidh : tidh
# tersisa : sisa
# kemarinnya : kemarin
# gakjelas : gakjelas
# ratingnyabarusan : ratingnyabarusan
# matanya : mata
# rabun : rabun
# pempin : pempin
# ces : ces
# pemimpin : pimpin
# upgarde : upgarde
# teroooosssss : teroooosssss
# downgrade : downgrade
# aplikasilayanan : aplikasilayanan
# diotakatik : diotakatik
# nyusain : nyusain
# alah : alah
# vertufikasi : vertufikasi
# aii : aii
# pengmbalian : pengmbalian
# sertakan : serta
# laaa : laaa
# gmnsegera : gmnsegera
# menggigit : gigit
# maklum : maklum
# terpesan : pes
# mkzih : mkzih
# sofar : sofar
# sogood : sogood
# msen : msen
# mknn : mknn
# isriwil : isriwil
# clear : clear
# gobok : gobok
# onliin : onliin
# indonesiasaya : indonesiasaya
# banyumas : banyumas
# diadakangobok : diadakangobok
# dijakartatrima : dijakartatrima
# kasiih : kasiih
# mihil : mihil
# notip : notip
# betmutt : betmutt
# hapu : hapu
# drivr : drivr
# ufah : ufah
# lemmod : lemmod
# nye : nye
# pelangan : pelang
# brio : brio
# datsun : datsun
# panca : panca
# bagusdisiplinkan : bagusdisiplinkan
# gembira : gembira
# proaktif : proaktif
# produktif : produktif
# bersenang : senang
# piknik : piknik
# mengembangkan : kembang
# aslii : asli
# merayapsibuk : merayapsibuk
# nyebelingabisa : nyebelingabisa
# luxe : luxe
# pollbiasanya : pollbiasanya
# ketulungan : ketulungan
# dites : tes
# transakti : transakti
# uninstalldiinstall : uninstalldiinstall
# akhirnyagak : akhirnyagak
# adajadi : adajadi
# banyakkan : banyak
# yabuka : yabuka
# bisaloading : bisaloading
# mulukenapa : mulukenapa
# selera : selera
# gawat : gawat
# buatke : buatke
# badahal : badahal
# sesuailebih : sesuailebih
# allahuakbar : allahuakbar
# ekstra : ekstra
# merespons : respons
# kenapaya : kenapaya
# helps : helps
# sumpahhh : sumpahhh
# burukkkkk : burukkkkk
# dicekout : dicekout
# gambarnya : gambar
# ngebeleng : ngebeleng
# bayarbuka : bayarbuka
# luaaamaaa : luaaamaaa
# ampunpdhl : ampunpdhl
# keganti : ganti
# teledor : teledor
# tibah : tibah
# bankmakin : bankmakin
# resmi : resmi
# lembaga : lembaga
# terjamin : jamin
# minsaya : minsaya
# terkenal : kenal
# menggunakanterlalu : menggunakanterlalu
# digunakanntah : digunakanntah
# buyar : buyar
# maintenance : maintenance
# performanya : performa
# aplik : aplik
# hooaylater : hooaylater
# jawabn : jawabn
# snyal : snyal
# dibagusin : dibagusin
# loding : loding
# bosokkk : bosokkk
# crashh : crashh
# nalarlagi : nalarlagi
# dongo : dongo
# gopai : gopai
# gamasuk : gamasuk
# nubjelas : nubjelas
# bagusdr : bagusdr
# gabisaada : gabisaada
# jamujungnya : jamujungnya
# dibilng : dibilng
# burukmuka : burukmuka
# enggaa : enggaa
# sinya : sinya
# lemahpadahal : lemahpadahal
# unfollow : unfollow
# byeeeee : byeeeee
# ribetttt : ribetttt
# pemberitahuannya : pemberitahuannya
# markotopjoosssee : markotopjoosssee
# gandoosse : gandoosse
# normalnya : normal
# keambil : ambil
# halah : halah
# ngacoklo : ngacoklo
# susahtambah : susahtambah
# bodat : bodat
# leletvmau : leletvmau
# douwnload : douwnload
# dikiirim : dikiirim
# motifnya : motif
# ngeriset : ngeriset
# critanya : critanya
# buffring : buffring
# dibukakasih : dibukakasih
# gragra : gragra
# cras : cras
# scab : scab
# minuntuk : minuntuk
# relogin : relogin
# lahaq : lahaq
# still : still
# errormya : errormya
# yasama : yasama
# pikih : pikih
# pembayarannyaudh : pembayarannyaudh
# nihmalah : nihmalah
# pakeapk : pakeapk
# comment : comment
# diupdated : diupdated
# bersihin : bersihin
# bisaaaa : bisaaaa
# kupake : kupake
# aahhh : aahhh
# aplikasiii : aplikasiii
# parahhhhhhhhhh : parahhhhhhhhhh
# ngebles : ngebles
# nampil : nampil
# cct : cct
# dongs : dongs
# penemuan : temu
# ngblank : ngblank
# dijawa : dijawa
# samarinda : samarinda
# dipatok : patok
# apergerakan : apergerakan
# datenynya : datenynya
# ngehank : ngehank
# penderitaan : derita
# aeribg : aeribg
# salso : salso
# paykater : paykater
# ude : ude
# nghanggg : nghanggg
# jlss : jlss
# masukkkk : masukkkk
# aplikasihnye : aplikasihnye
# wkwkk : wkwkk
# bunda : bunda
# recomendeddd : recomendeddd
# suue : suue
# wooosshhh : wooosshhh
# amanh : amanh
# hrga : hrga
# gopaylter : gopaylter
# marketting : marketting
# hawa : hawa
# liburan : libur
# angkotmending : angkotmending
# iyhkapok : iyhkapok
# nyamanini : nyamanini
# perkuat : kuat
# kamisudah : kamisudah
# jawabanmohon : jawabanmohon
# judul : judul
# sambungan : sambung
# jelaspas : jelaspas
# makannan : makannan
# terhenti : henti
# suparno : suparno
# ikutan : ikut
# gueh : gueh
# luwh : luwh
# mencemarkan : cemar
# kobocha : kobocha
# kompeten : kompeten
# memakainya : maka
# murah meriah : murah riah
# lagu : lagu
# laguangopay : laguangopay
# paylaterwkkwkwk : paylaterwkkwkwk
# pengkinian : kini
# open : open
# rasanyakalau : rasanyakalau
# ajabikin : ajabikin
# ajagak : ajagak
# cepaton : cepaton
# timesesuai : timesesuai
# mboh : mboh
# mappeta : mappeta
# dibuatin : dibuatin
# dihapuslebih : dihapuslebih
# findana : findana
# mabmakanya : mabmakanya
# mingguan : minggu
# teriak : teriak
# ketolak : tolak
# mantapselalu : mantapselalu
# aplikasititik : aplikasititik
# transparan : transparan
# radius : radius
# kompleks : kompleks
# kontrol : kontrol
# bangetsangat : bangetsangat
# ajaotp : ajaotp
# langgan : langgan
# baguspengiriman : baguspengiriman
# goput : goput
# klp : klp
# komplek : komplek
# forced : forced
# apklikasi : apklikasi
# tololupgrade : tololupgrade
# mulujadi : mulujadi
# dikurangin : rangin
# prah : prah
# orderpun : order
# deivernya : deivernya
# nurani : nurani
# dreivernya : dreivernya
# lengka : lengka
# panik : panik
# pnasan : pnasan
# layanin : layanin
# penyelsaian : penyelsaian
# gocengbuat : gocengbuat
# alam : alam
# remote : remote
# toloooolll : toloooolll
# gabisaaa : gabisaaa
# anjiiinnkkkkkkk : anjiiinnkkkkkkk
# odran : odran
# alamatny : alamatny
# nanyain : nanyain
# menjelang : jelang
# subuh : subuh
# tindaklanjuti : tindaklanjuti
# gofoodsll : gofoodsll
# zainalganti : zainalganti
# indraganti : indraganti
# jayasy : jayasy
# hematsy : hematsy
# ajari : ajar
# laje : laje
# mobile : mobile
# padhal : padhal
# bagt : bagt
# berbagi : bagi
# loba : loba
# tawaran : tawar
# antarnyatolong : antarnyatolong
# rbnanti : rbnanti
# diperpanjang : panjang
# berlakunya : laku
# berbulan : bulan
# bulandan : bulandan
# lunasihabis : lunasihabis
# dibekukandan : dibekukandan
# aktifterus : aktifterus
# berbelit : belit
# belitgak : belitgak
# ajarespon : ajarespon
# asix : asix
# playter : playter
# anis : anis
# kampanye : kampanye
# dicancell : dicancell
# menitterlebih : menitterlebih
# murahdan : murahdan
# ongkoskalau : ongkoskalau
# kekantor : kantor
# lagiamingggg : lagiamingggg
# layanannyaa : layanannyaa
# terpenuhi : penuh
# lokasitiba : lokasitiba
# dibukatadiy : dibukatadiy
# dikecewakan : kecewa
# ampir : ampir
# dilama : lama
# lamain : lamain
# promoatau : promoatau
# diriview : diriview
# reviewnya : reviewnya
# surga : surga
# pelitngasih : pelitngasih
# vocerr : vocerr
# mnurut : mnurut
# gate : gate
# geng : geng
# draverny : draverny
# selamatkan : selamat
# gojeknyaa : gojeknyaa
# grabshopee : grabshopee
# ilanh : ilanh
# tae : tae
# terhambat : hambat
# emgnya : emgnya
# jelekgk : jelekgk
# gooooood : gooooood
# teknik : teknik
# marketing : marketing
# ketaun : taun
# senag : senag
# mirah : mirah
# drivernyaa : drivernyaa
# hengggg : hengggg
# teroooosssssss : teroooosssssss
# kesedot : sedot
# setau : tau
# kepemilikan : milik
# dicurigai : curiga
# casback : casback
# booangan : booangan
# pdam : pdam
# percuuma : percuuma
# invest : invest
# muantabbbb : muantabbbb
# ckckckckkck : ckckckckkck
# beneeerr : beneeerr
# wkwkwkwkwkwk : wkwkwkwkwkwk
# menyikapi : sikap
# mengendap : endap
# gopayke : gopayke
# bankdi : bankdi
# seribet : seribet
# sekalidan : sekalidan
# tttt : tttt
# ooo : ooo
# galuh : galuh
# digi : digi
# indra : indra
# pradana : pradana
# cengcengcik : cengcengcik
# mikilkan : mikilkan
# maraneh : maraneh
# alesanna : alesanna
# nu : nu
# ngebulkan : ngebulkan
# geus : geus
# deal : deal
# dibere : dibere
# sakitugeus : sakitugeus
# pamolahteu : pamolahteu
# ayana : ayana
# ieumakin : ieumakin
# nyarande : nyarande
# tangkalnu : tangkalnu
# biasana : biasana
# poe : poe
# ngebulkeun : ngebulkeun
# dapurayeuna : dapurayeuna
# meureun : meureun
# dapurna : dapurna
# ngebul : ngebul
# titipan : titip
# tksh : tksh
# avaible : avaible
# sangatm : sangatm
# kamii : kami
# tranpotasi : tranpotasi
# gojekuntuk : gojekuntuk
# hematsetelah : hematsetelah
# olah : olah
# areaparah : areaparah
# jerih : jerih
# payahnya : payah
# aplikasinyaaaa : aplikasinyaaaa
# kelakuan : laku
# provoder : provoder
# penjmputan : penjmputan
# pengirimny : pengirimny
# cptdrivery : cptdrivery
# sopn : sopn
# pembiayaan : biaya
# gojekmending : gojekmending
# gabisaa : gabisaa
# pembyaran : pembyaran
# lainsy : lainsy
# ngomongsolusi : ngomongsolusi
# gmnaapelayanan : gmnaapelayanan
# bngung : bngung
# kemrin : kemrin
# himbau : himbau
# katnya : katnya
# sampa : sampa
# pemberi : beri
# tahuan : tahu
# toped : toped
# blanjaan : blanjaan
# pmbayran : pmbayran
# perbulanya : perbulanya
# mencicil : cicil
# ketjeh : ketjeh
# gonearby : gonearby
# viralin : viralin
# es : es
# cream : cream
# soto : soto
# bagusberguna : bagusberguna
# kmdatang : kmdatang
# mayit : mayit
# terpopuler : populer
# notiv : notiv
# utuh : utuh
# terkocak : kocak
# bengek : bengek
# pou : pou
# dongomahal : dongomahal
# mahalsampe : mahalsampe
# arfo : arfo
# nyaplok : nyaplok
# gedee : gedee
# mari : mari
# kehancuran : hancur
# aplikayyg : aplikayyg
# hubungan : hubung
# costumermakin : costumermakin
# bangsaat : bangsaat
# sayaada : sayaada
# buktidan : buktidan
# cekuang : cekuang
# bermingguminggu : bermingguminggu
# mandi : mandi
# baju : baju
# mual : mual
# gojekkalo : gojekkalo
# ngasaltidak : ngasaltidak
# apasi : apas
# bagussramah : bagussramah
# ws : ws
# aseek : aseek
# membacanya : baca
# kesannya : kesan
# base : base
# samasama : samasama
# masingmasing : masingmasing
# muu : muu
# bangus : bangus
# jugah : jugah
# menindas : tindas
# ktrima : ktrima
# ksian : ksi
# ege : ege
# iwh : iwh
# daerahku : daerah
# okcepat : okcepat
# cashbacknya : cashbacknya
# teransaksi : teransaksi
# erorkadang : erorkadang
# qrisberbagai : qrisberbagai
# ngeriidata : ngeriidata
# bocorseaman : bocorseaman
# diinfo : info
# ongkosin : ongkosin
# ngacok : ngacok
# iyhhh : iyhhh
# ttc : ttc
# fr : fr
# ruji : ruji
# bmmllk : bmmllk
# uu : uu
# jkl : jkl
# rri : rri
# re : re
# reryg : reryg
# jr : jr
# serakah : serakah
# cina : cina
# biadab : biadab
# driverl : driverl
# musnahin : musnahin
# mantullmurah : mantullmurah
# taeklah : taeklah
# dajjal : dajjal
# finansialnya : finansial
# mendig : mendig
# dklin : dklin
# pemesana : sana
# memesankan : mesan
# memudahkanini : memudahkanini
# nik : nik
# lahdata : lahdata
# database : database
# lahgua : lahgua
# amanaja : amanaja
# pengantaranya : antara
# gaikhlas : gaikhlas
# semangatrung : semangatrung
# nganti : nganti
# angop : angop
# wis : wis
# ketok : ketok
# mantaaaab : mantaaaab
# gojekjd : gojekjd
# peribadi : peribadi
# mencetnya : mencetnya
# beliau : beliau
# damai : damai
# jiplak : jiplak
# bacanya : baca
# obrolan : obrol
# pngabtran : pngabtran
# mntan : mntan
# sistemnyatolong : sistemnyatolong
# mcd : mcd
# fooddi : fooddi
# mahaltpi : mahaltpi
# rugiongkir : rugiongkir
# pengantarnya : antar
# jauhouh : jauhouh
# begituopsss : begituopsss
# kenapaapdet : kenapaapdet
# memudahan : mudah
# nyampeknya : nyampeknya
# hapuskan : hapus
# permuk : muk
# sucks : sucks
# matabb : matabb
# tiptambahan : tiptambahan
# jelastiba : jelastiba
# disabel : sabel
# gudeg : gudeg
# mnurutku : mnurutku
# banyaaakkk : banyaaakkk
# yaaaahhhh : yaaaahhhh
# simpati : simpati
# jelasssssmakin : jelasssssmakin
# jelassss : jelassss
# potensi : potensi
# goco : goco
# memelas : memelas
# nomral : nomral
# filiran : filiran
# minjam : minjam
# nawar : nawar
# gooay : gooay
# pimjem : pimjem
# gojegemang : gojegemang
# tunjukkan : tunjuk
# akunya : aku
# dongoo : dongoo
# mengemis : emis
# nyaudh : nyaudh
# lancarajh : lancarajh
# yolong : yolong
# perempuan : perempuan
# indrer : indrer
# maxm : maxm
# hempaskan : hempas
# november : november
# diorder : order
# heboh : heboh
# kesituahh : kesituahh
# ngobrolnya : ngobrolnya
# mintangemis : mintangemis
# terangan : terang
# angkutan : angkut
# bestlah : bestlah
# lebihan : lebih
# alfamartnya : alfamartnya
# tmpilan : tmpilan
# walet : walet
# tmpat : tmpat
# gopaygojek : gopaygojek
# yatim : yatim
# fahmi : fahmi
# aziz : aziz
# unm : unm
# ajaaturan : ajaaturan
# petanya : peta
# manjat : manjat
# dipotongnya : potong
# persentase : persentase
# punyanya : punya
# tegang : tegang
# gojekknp : gojekknp
# jelassaya : jelassaya
# primakemanusiaan : primakemanusiaan
# jugarisih : jugarisih
# kesayanyasaya : kesayanyasaya
# keluhannya : keluh
# kacung : kacung
# brimosaldo : brimosaldo
# brimo : brimo
# tutuphapus : tutuphapus
# pemabayaran : pemabayaran
# transaksitidak : transaksitidak
# sparepart : sparepart
# tahukah : tahu
# bengkel : bengkel
# rekanan : rekan
# sparepartnya : sparepartnya
# kampas : kampas
# rem : rem
# imbasnya : imbas
# pakem : pakem
# brake : brake
# rotor : rotor
# piringan : piring
# cakram : cakram
# gotolil : gotolil
# diklaim : klaim
# dimenu : menu
# dimsum : dimsum
# insiden : insiden
# kecelakaan : celaka
# memohon : mohon
# lbhkan : lbhkan
# rbgmn : rbgmn
# menjerit : jerit
# itutolong : itutolong
# pemales : pales
# coy : coy
# halbaik : halbaik
# ambles : ambles
# bkalan : bkalan
# berpa : berpa
# kapitalis : kapitalis
# kamera : kamera
# malahh : malahh
# tangapin : tangapin
# mengaku : aku
# sekarangsekarang : sekarangsekarang
# pengambilaan : pengambilaan
# cepetprofesi : cepetprofesi
# pertengahan : tengah
# orngnya : orngnya
# dulcapil : dulcapil
# membantusy : membantusy
# hrp : hrp
# upapa : upapa
# under : under
# empati : empati
# jgnkan : jgnkan
# jauhdan : jauhdan
# berdering : dering
# mesenin : mesenin
# dipermainkan : main
# parrrahh : parrrahh
# lebihdari : lebihdari
# tersebutaaminn : tersebutaaminn
# aaah : aaah
# gkbs : gkbs
# susaahh : susaahh
# okeeeee : okeeeee
# membantudan : membantudan
# kendalakendala : kendalakendala
# cepatterimakasih : cepatterimakasih
# buagussss : buagussss
# berilah : ilah
# rbsetiap : rbsetiap
# tibatibageser : tibatibageser
# onkosnya : onkosnya
# cacad : cacad
# penggunaaku : penggunaaku
# serint : serint
# worthy : worthy
# sentosa : sentosa
# yaiya : yaiya
# mengecewakandi : mengecewakandi
# bukasdh : bukasdh
# lgtetap : lgtetap
# dibwaha : dibwaha
# judi : judi
# kenapaaaaaa : kenapaaaaaa
# terhalang : halang
# sistemnyaaaaa : sistemnyaaaaa
# preman : preman
# pancing : pancing
# goodd : goodd
# bearti : bearti
# jayaheee : jayaheee
# anji : anji
# wr : wr
# wb : wb
# lekk : lekk
# balek : balek
# unistalinstal : unistalinstal
# angus : angus
# gojekkkkk : gojekkkkk
# orngsaya : orngsaya
# indonesiateramat : indonesiateramat
# ribukalian : ribukalian
# ongkoso : ongkoso
# kirimkenapa : kirimkenapa
# perbaikijangan : perbaikijangan
# ops : ops
# berharihari : berharihari
# belaku : bela
# sukabumi : sukabumi
# beritahukan : beritahukan
# berubi : ubi
# discountdiacountnya : discountdiacountnya
# promosipromosinya : promosipromosinya
# imissmyman : imissmyman
# mat : mat
# cin : cin
# leeeemooooooooottttttt : leeeemooooooooottttttt
# baaaaaangeeettt : baaaaaangeeettt
# rabb : rabb
# gimanasi : gimanasi
# yosh : yosh
# transasi : transasi
# dpat : dpat
# bayarklu : bayarklu
# lagigak : lagigak
# djancok : djancok
# drvier : drvier
# ampasnya : ampas
# diturunkanbagaimana : diturunkanbagaimana
# bulat : bulat
# startup : startup
# fvckkkk : fvckkkk
# maruk : maruk
# minmslh : minmslh
# keukeuh : keukeuh
# almat : almat
# sbnrnya : sbnrnya
# mengulang : ulang
# anakbangsa : anakbangsa
# terupdate : terupdate
# mix : mix
# meredakan : reda
# keterimanya : terima
# keterima : terima
# mangkas : mangkas
# onik : onik
# waow : waow
# ngode : ngode
# wkkwkw : wkkwkw
# banya : banya
# ditinggilan : ditinggilan
# hilangpea : hilangpea
# penifu : penifu
# mengaca : kaca
# diperiksa : periksa
# imbalan : imbal
# nohh : nohh
# gblllk : gblllk
# njikn : njikn
# setiapp : setiapp
# upgrede : upgrede
# promosikan : promosi
# berteletele : berteletele
# begituan : begitu
# jambret : jambret
# mukanya : muka
# pengungsi : ungsi
# rohingnyaudah : rohingnyaudah
# kuceljaketnya : kuceljaketnya
# kelabang : kelabang
# mungut : mungut
# driper : driper
# ongol : ongol
# tiplebihsdgkn : tiplebihsdgkn
# besarud : besarud
# makananakeburu : makananakeburu
# plerkuda : plerkuda
# careservice : careservice
# gojekjujur : gojekjujur
# ngechat : ngechat
# mengharapkan : harap
# kamiyg : kamiyg
# tapu : tapu
# persediaan : sedia
# abuabu : abuabu
# antarkan : antar
# follow : follow
# moode : moode
# kuasai : kuasa
# hahahaha : hahahaha
# gacorrr : gacorrr
# termudah : mudah
# anjrt : anjrt
# pelitttt : pelitttt
# dih : dih
# muludrivernya : muludrivernya
# manusiakan : manusia
# semuaaplikator : semuaaplikator
# customerdriver : customerdriver
# customercustomer : customercustomer
# terkaitrubah : terkaitrubah
# benerjangan : benerjangan
# acengterima : acengterima
# balesaannya : balesaannya
# utarakan : utara
# nyesal : nyesal
# gojekgoride : gojekgoride
# kelanjutan : lanjut
# au : au
# bergunabed : bergunabed
# gakaru : gakaru
# ngunu : ngunu
# lemooooot : lemooooot
# paeah : paeah
# merdekasekarang : merdekasekarang
# luamaaa : luamaaa
# bgtsampai : bgtsampai
# driverapa : driverapa
# perangdan : perangdan
# ewerpdhl : ewerpdhl
# ewertolong : ewertolong
# orderansya : orderansya
# dulusat : dulusat
# setlhas : setlhas
# lhes : lhes
# yadi : yad
# teknologi : teknologi
# diancem : diancem
# nyamahal : nyamahal
# gppmalah : gppmalah
# office : office
# ambruk : ambruk
# nyatapi : nyatapi
# mudahmurahgoodjob : mudahmurahgoodjob
# beresgak : beresgak
# nunggakkkk : nunggakkkk
# dipermasalahin : dipermasalahin
# jelasmau : jelasmau
# setujui : tuju
# pembayaranny : pembayaranny
# kelian : kelian
# tuparah : tuparah
# mangap : mangap
# lirik : lirik
# kanan : kanan
# kiri : kiri
# beki : bek
# ahk : ahk
# memas : mas
# balikkan : balik
# gd : gd
# buatt : buatt
# revaaa : revaaa
# taukkkkkkkkk : taukkkkkkkkk
# hummmmmm : hummmmmm
# sahabat : sahabat
# karib : karib
# memaki : maki
# kalem : kalem
# yskrg : yskrg
# cstmr : cstmr
# sbentar : sbentar
# bangkrutnya : bangkrut
# tertagih : tagih
# tolakin : tolakin
# interior : interior
# kalai : kalai
# join : join
# kontrak : kontrak
# masukaplikasi : masukaplikasi
# paraahhhh : paraahhhh
# hargain : hargain
# ngarepin : ngarepin
# dibatal : batal
# servisnya : servis
# oopp : oopp
# orderbiar : orderbiar
# pengantarantidak : pengantarantidak
# wajarkan : wajar
# pakir : pakir
# testoapa : testoapa
# ngerepotin : ngerepotin
# awaly : awaly
# gojekgopaylater : gojekgopaylater
# superb : superb
# dllsetiap : dllsetiap
# gregetan : gregetan
# helpchat : helpchat
# norespon : norespon
# ngerisedap : ngerisedap
# klarifikasi : klarifikasi
# gndala : gndala
# mintpi : mintpi
# uwaw : uwaw
# pencurian : curi
# melapornya : lapor
# belagukalau : belagukalau
# loggin : loggin
# nyatolong : nyatolong
# dibenahikami : dibenahikami
# ditipu : tipu
# manaa : manaa
# ngerecruit : ngerecruit
# penjemputanx : penjemputanx
# biak : biak
# papua : papua
# pencerahan : cerah
# pahlawan : pahlawan
# ditawarin : ditawarin
# rebudriver : rebudriver
# lagibuset : lagibuset
# yamana : yamana
# pengantarannya : antar
# ketidaknyamanan : ketidaknyamanan
# penghapusan : hapus
# disalah : salah
# penonaktifan : nonaktif
# diapa : apa
# develop : develop
# bangeetsusah : bangeetsusah
# dapetnyapercuma : dapetnyapercuma
# foodkok : foodkok
# mahaljadi : mahaljadi
# risihdengan : risihdengan
# gojekkita : gojekkita
# sampenya : sampenya
# terrnyata : terrnyata
# kontolll : kontolll
# puasss : puasss
# ygg : ygg
# different : different
# perbaikiin : perbaikiin
# huhu : huhu
# lagidengan : lagidengan
# berjutajuta : berjutajuta
# gpay : gpay
# debitnya : debit
# flagship : flagship
# mabuk : mabuk
# aogonh : aogonh
# frezze : frezze
# owalah : owalah
# trimah : trimah
# tanggungjawabnya : tanggungjawabnya
# ktol : ktol
# cocokmantap : cocokmantap
# pemalakan : mala
# membantuusahakan : membantuusahakan
# iyya : iyya
# rogoh : rogoh
# kocek : kocek
# whaaattsss : whaaattsss
# jumatan : jumat
# driveryg : driveryg
# covid : covid
# kabarnya : kabar
# ngimbas : ngimbas
# mantulllll : mantulllll
# gaiss : gaiss
# mantaaaap : mantaaaap
# rekomendasikan : rekomendasi
# gajinya : gaji
# lola : lola
# kedeteksi : deteksi
# nadia : nadia
# omara : omara
# menyempurnakan : sempurna
# tekhnis : tekhnis
# before : before
# jelaspesan : jelaspesan
# isya : isya
# sibukaplikasi : sibukaplikasi
# hdm : hdm
# olh : olh
# xwl : xwl
# hnco : hnco
# zf : zf
# dqr : dqr
# bxt : bxt
# xae : xae
# menghadirkan : hadir
# duanya : dua
# ridegocar : ridegocar
# thk : thk
# pure : pure
# dbessaku : dbessaku
# laters : laters
# astagfirullah : astagfirullah
# mengecewakansupirnya : mengecewakansupirnya
# ngegas : ngegas
# ngehangtiba : ngehangtiba
# future : future
# amanpuas : amanpuas
# bodong : bodong
# mulugabisa : mulugabisa
# anggotapelanggan : anggotapelanggan
# ttup : ttup
# flickering : flickering
# tlponin : tlponin
# heyyyyy : heyyyyy
# enakin : enakin
# sengsarain : sengsarain
# nyacuma : nyacuma
# gopathner : gopathner
# menghadapi : hadap
# money : money
# apaapaan : apaapaan
# siapsiap : siapsiap
# multifinance : multifinance
# meneror : teror
# market : market
# joosh : joosh
# manatap : manatap
# kereendriver : kereendriver
# handal : handal
# semuanyagood : semuanyagood
# membantuharga : membantuharga
# terjangkausukses : terjangkausukses
# skng : skng
# ish : ish
# bjir : bjir
# ancen : ancen
# gendeng : gendeng
# bgaruh : bgaruh
# upnya : upnya
# ditraining : ditraining
# coins : coins
# nuce : nuce
# ngelaq : ngelaq
# lovyu : lovyu
# boikot : boikot
# finally : finally
# desain : desain
# ilustrasinyaaaa : ilustrasinyaaaa
# ngagur : ngagur
# taikk : taikk
# trhambat : trhambat
# gosenthks : gosenthks
# kal : kal
# laingimna : laingimna
# riset : riset
# dipribet : dipribet
# cuih : cuih
# heheini : heheini
# busy : busy
# daruratmana : daruratmana
# semugabisa : semugabisa
# meringani : ringan
# harisaya : harisaya
# masukpadah : masukpadah
# pluskbalikan : pluskbalikan
# pemasan : mas
# transjakarta : transjakarta
# busway : busway
# vending : vending
# machine : machine
# buswaynya : buswaynya
# payahhhh : payahhhh
# mantullle : mantullle
# bulak : bulak
# respondnya : respondnya
# sipmantap : sipmantap
# dekatargo : dekatargo
# jemut : jemut
# anternyapun : anter
# palkir : palkir
# belasan : bas
# updategopay : updategopay
# jelasss : jelasss
# babu : babu
# kwn : kwn
# warnet : warnet
# plisss : plisss
# multi : multi
# telen : telen
# hahahahahhaah : hahahahahhaah
# pemeliharaan : pelihara
# ngeraup : ngeraup
# sebanyakbanyaknya : sebanyakbanyaknya
# gabalik : gabalik
# remaja : remaja
# latest : latest
# erorudh : erorudh
# lost : lost
# daaa : daaa
# mav : mav
# costamer : costamer
# njiirrr : njiirrr
# perasaa : perasaa
# temponya : tempo
# blokiran : blokir
# gobilsss : gobilsss
# digunakansedangkan : digunakansedangkan
# cukupmau : cukupmau
# deehh : deehh
# lockdownmm : lockdownmm
# refundlama : refundlama
# refundtolong : refundtolong
# hadeuuuuh : hadeuuuuh
# nggada : nggada
# ggup : ggup
# masok : masok
# drivecar : drivecar
# mendinglah : mending
# inetnya : inetnya
# bugsnya : bugsnya
# keseringan : sering
# suspen : suspen
# knpaaa : knpaaa
# kapann : kapann
# miskom : miskom
# ngap : ngap
# gakami : gakami
# animasicoz : animasicoz
# fiktifjd : fiktifjd
# sampekt : sampekt
# mapsmau : mapsmau
# denah : denah
# inijadi : inijadi
# hank : hank
# hengnge : hengnge
# frezzeeee : frezzeeee
# lngs : lngs
# skrkenapa : skrkenapa
# sihbikin : sihbikin
# trsdikit : trsdikit
# trscapek : trscapek
# dehkasian : dehkasian
# maklumi : maklum
# diputer : puter
# teruskan : terus
# ngrepotin : ngrepotin
# jelassaldo : jelassaldo
# hilangpadahal : hilangpadahal
# duhcs : duhcs
# downloadbaru : downloadbaru
# ketikehhhhlah : ketikehhhhlah
# fungsinya : fungsi
# inisiatif : inisiatif
# kesni : kesni
# oayah : oayah
# diapakan : apa
# hadehhhh : hadehhhh
# tampilannya : tampil
# selebew : selebew
# selig : selig
# nglag : nglag
# apple : apple
# musik : musik
# kedebet : debet
# diperdulit : diperdulit
# invoicenya : invoicenya
# konsumensy : konsumensy
# nyatdk : nyatdk
# keterlambatannya : lambat
# ngab : ngab
# maksutnya : maksutnya
# babbi : babbi
# kebuang : buang
# asyuu : asyuu
# menjahati : jahat
# sebanyaknya : banyak
# gangguannya : ganggu
# downlod : downlod
# gobloknya : goblok
# kehack : kehack
# berhentikan : henti
# oll : oll
# bertabur : tabur
# dluskrg : dluskrg
# doangnunggu : doangnunggu
# gdpt : gdpt
# ajapas : ajapas
# updt : updt
# erormau : erormau
# ramahmn : ramahmn
# anehhhhhh : anehhhhhh
# gampank : gampank
# sensitif : sensitif
# crypto : crypto
# punt : punt
# bimgung : bimgung
# disalahin : disalahin
# sidoarjo : sidoarjo
# lek : lek
# aras : aras
# arasen : arasen
# kerjo : kerjo
# tambak : tambak
# gae : gae
# mancing : mancing
# anu : anu
# makananan : makananan
# gajelaaas : gajelaaas
# omongan : omong
# selver : selver
# peraktis : peraktis
# pcsjarak : pcsjarak
# meternungguin : meternungguin
# stngah : stngah
# lebihyang : lebihyang
# ice : ice
# penyakitan : sakit
# batuk : batuk
# batasan : batas
# errorrr : errorrr
# tantrum : tantrum
# foreclose : foreclose
# bobrooooook : bobrooooook
# temoat : temoat
# lancarsaya : lancarsaya
# keseludah : ludah
# respek : respek
# snapdragon : snapdragon
# gen : gen
# joosss : joosss
# perintahnya : perintah
# gerai : gerai
# input : input
# bugny : bugny
# skarng : skarng
# temenku : temenku
# benalu : benalu
# gado : gado
# stok : stok
# hadehhhhhhh : hadehhhhhhh
# ook : ook
# masuknunggu : masuknunggu
# kuciwa : kuciwa
# regular : regular
# shopefood : shopefood
# pasan : pas
# wak : wak
# receipt : receipt
# iniblm : iniblm
# responsaya : responsaya
# sayasoalnya : sayasoalnya
# sayaklu : sayaklu
# tampilanya : tampilanya
# makasii : makasii
# interaktif : interaktif
# pajaknya : pajak
# transpotasi : transpotasi
# insidentil : insidentil
# kitakita : kitakita
# motorhehehe : motorhehehe
# ripuh : ripuh
# dtiver : dtiver
# rekomend : rekomend
# sulusi : sulusi
# manap : manap
# ep : ep
# tdny : tdny
# scroll : scroll
# diacakkalau : diacakkalau
# terjadk : terjadk
# te : te
# tep : tep
# apkikasji : apkikasji
# apabanyak : apabanyak
# dreaver : dreaver
# klub : klub
# peringkat : peringkat
# rawww : rawww
# jlan : jlan
# perboden : perboden
# dinotifnya : dinotifnya
# tabungab : tabungab
# pembisnissistem : pembisnissistem
# unsintal : unsintal
# selancar : selancar
# brgkt : brgkt
# skola : skola
# gobris : gobris
# toleransi : toleransi
# udaa : udaa
# janganjangan : janganjangan
# koropsi : koropsi
# mantablah : mantablah
# woyylo : woyylo
# lahmasa : lahmasa
# mahaldn : mahaldn
# gocengemngnya : gocengemngnya
# drivernyabensin : drivernyabensin
# mahalgua : mahalgua
# tegadriver : tegadriver
# kutana : kutana
# mantappselalu : mantappselalu
# lalot : lalot
# lainhati : lainhati
# gopayhutang : gopayhutang
# rbdan : rbdan
# tahunsangat : tahunsangat
# mengecewakanayo : mengecewakanayo
# mantel : mantel
# bapaknya : bapak
# kehujanan : hujan
# burikkk : burikkk
# kontek : kontek
# bagaimanaaaaa : bagaimanaaaaa
# dalamnya : dalam
# sambungin : sambungin
# invalid : invalid
# njs : njs
# aduuuhhhh : aduuuhhhh
# debitsemua : debitsemua
# tunaigimana : tunaigimana
# gampangg : gampangg
# dimakanin : dimakanin
# bintangsoalnya : bintangsoalnya
# errorlengket : errorlengket
# layarbalik : layarbalik
# home : home
# kokpakai : kokpakai
# nghang : nghang
# bereaksi : reaksi
# okw : okw
# ngen : ngen
# buangett : buangett
# susahsering : susahsering
# nyamantepat : nyamantepat
# rilex : rilex
# dipakaimaksudnya : dipakaimaksudnya
# telattt : telattt
# ibuk : ibuk
# kakek : kakek
# nenek : nenek
# fbynllhpgnmid : fbynllhpgnmid
# cmeunxlivmid : cmeunxlivmid
# bxs : bxs
# ekfetif : ekfetif
# memnantu : memnantu
# pengenbalian : pengenbalian
# gubris : gubris
# parang : parang
# goodcukup : goodcukup
# angkatan : angkat
# malm : malm
# apknyamending : apknyamending
# trmksig : trmksig
# kanyokkkk : kanyokkkk
# jenuh : jenuh
# lahgojeg : lahgojeg
# ho : ho
# jadahbikinan : jadahbikinan
# benerlu : benerlu
# apdi : apdi
# ataskok : ataskok
# sajamudah : sajamudah
# perbolehkan : boleh
# mantapbe : mantapbe
# ngerepoti : ngerepoti
# investasi : investasi
# sil : sil
# kendaraanbisa : kendaraanbisa
# belanjasukses : belanjasukses
# okemantap : okemantap
# erortidk : erortidk
# pembayarn : pembayarn
# aplksinya : aplksinya
# nyampesekarang : nyampesekarang
# pe : pe
# andelinpdhl : andelinpdhl
# galbay : galbay
# dipantau : pantau
# donload : donload
# berapaa : berapaa
# dibukaa : dibukaa
# disuru : disuru
# kumaahaaaaa : kumaahaaaaa
# etaa : etaa
# urang : urang
# bayaarrrrnyaa : bayaarrrrnyaa
# meninggal : tinggal
# peraturanya : peraturanya
# parahhhanehh : parahhhanehh
# kampretlah : kampret
# kacaj : kacaj
# hadehini : hadehini
# yamasa : yamasa
# premgopay : premgopay
# risi : risi
# akrifkan : akrifkan
# lapir : lapir
# tok : tok
# doc : doc
# pikirin : pikirin
# dimasukkan : masuk
# mempermuda : muda
# tangga : tangga
# terosszz : terosszz
# solve : solve
# ngefreze : ngefreze
# palangkaraya : palangkaraya
# konyoljarak : konyoljarak
# efek : efek
# gobis : gob
# konflik : konflik
# driverresto : driverresto
# makann : makann
# dluan : dluan
# kerestodisisi : kerestodisisi
# jdkalo : jdkalo
# caancel : caancel
# saampai : saampai
# sekaraang : sekaraang
# jaaam : jaaam
# mllm : mllm
# daritadi : daritadi
# aadaa : aadaa
# drivel : drivel
# matikan : mati
# cokkkkkk : cokkkkkk
# nyebrang : nyebrang
# disasar : sasar
# kekny : kekny
# nyampek : nyampek
# nauzubillahiminzalik : nauzubillahiminzalik
# pelayananaya : pelayananaya
# pedas : pedas
# tidaklevel : tidaklevel
# chefpembuat : chefpembuat
# chef : chef
# direport : direport
# agat : agat
# disanksi : sanksi
# digandain : digandain
# driverpakw : driverpakw
# malessepi : malessepi
# mengoceh : oceh
# gka : gka
# diselesein : diselesein
# bangetyuijjjj : bangetyuijjjj
# grabfoodnya : grabfoodnya
# hue : hue
# bantai : bantai
# frendly : frendly
# jrk : jrk
# exp : exp
# pelayannaya : pelayannaya
# josz : josz
# sanggup : sanggup
# onder : onder
# andalann : andalann
# selaluuu : selaluuu
# inboxnya : inboxnya
# atome : atome
# finance : finance
# dipercya : dipercya
# ngeblang : ngeblang
# lamalama : lamalama
# lolooo : lolooo
# buyan : buyan
# msukan : msukan
# bpakibu : bpakibu
# larangan : larang
# merokok : rokok
# diedukasi : edukasi
# upkendalanya : upkendalanya
# ovodanashopeylink : ovodanashopeylink
# jamitu : jamitu
# messager : messager
# menjanjika : menjanjika
# angkatin : angkatin
# berdua : dua
# keponakan : keponakan
# tas : tas
# jugaac : jugaac
# beginisaya : beginisaya
# tolerir : tolerir
# tindk : tindk
# bagussaat : bagussaat
# digabung : gabung
# gojeknnya : gojeknnya
# sori : sori
# siools : siools
# sklpentol : sklpentol
# gedemantap : gedemantap
# bgtlangganan : bgtlangganan
# inisminggu : inisminggu
# masuksudah : masuksudah
# seadanya : ada
# ketambah : tambah
# liburchat : liburchat
# tentukantanpa : tentukantanpa
# kitamengesalkansaya : kitamengesalkansaya
# transportation : transportation
# indonesiaauto : indonesiaauto
# lovers : lovers
# kekeh : kekeh
# negatif : negatif
# berkaitan : kait
# zhiiippp : zhiiippp
# kreditnggk : kreditnggk
# terbilang : bilang
# pakeengalami : pakeengalami
# dunistall : dunistall
# pembeliannya : beli
# laylater : laylater
# noinal : noinal
# ongkirkatanya : ongkirkatanya
# aplikasiga : aplikasiga
# klien : klien
# miliarorder : miliarorder
# bubur : bubur
# hotel : hotel
# bintangjadi : bintangjadi
# sesulit : sulit
# applications : applications
# about : about
# exellence : exellence
# rusdinahur : rusdinahur
# din : din
# sag : sag
# kacauyang : kacauyang
# seringan : sering
# dobellebih : dobellebih
# tertukar : tukar
# berdalih : dalih
# pembajakan : baja
# peristiwa : peristiwa
# splikasi : splikasi
# pinjamaplikasi : pinjamaplikasi
# sensetional : sensetional
# ngibulnyamemberikan : ngibulnyamemberikan
# rbharga : rbharga
# zzzz : zzzz
# elatase : elatase
# selemot : lot
# laak : laak
# siapsigapramahoke : siapsigapramahoke
# saatgoodjobgoodluck : saatgoodjobgoodluck
# again : again
# semuasemoga : semuasemoga
# pkok : pkok
# alikasi : alikasi
# driverudah : driverudah
# drivernyakadang : drivernyakadang
# harapkan : harap
# downloadpadahal : downloadpadahal
# memperburuk : buruk
# aplnya : aplnya
# kambuh : kambuh
# dibenarkan : benar
# ajagimana : ajagimana
# bkny : bkny
# matok : matok
# mbok : mbok
# diotak : otak
# kelaperannnnnn : kelaperannnnnn
# serper : serper
# gabisaaaaa : gabisaaaaa
# ottokeeee : ottokeeee
# melulumalah : melulumalah
# ngedeksi : ngedeksi
# lokasibug : lokasibug
# ininyusahin : ininyusahin
# diteksi : teks
# kedetect : kedetect
# gojeeeek : gojeeeek
# wirawiri : wirawiri
# errorr : errorr
# quality : quality
# penggunapelanggan : penggunapelanggan
# terdekteksi : terdekteksi
# jancoekan : jancoekan
# gaguna : gaguna
# blokk : blokk
# kesempatan : sempat
# membaca : baca
# anjingmaling : anjingmaling
# drivermemetongi : drivermemetongi
# layayanan : layayanan
# batasin : batasin
# jedah : jedah
# yerdeteksi : yerdeteksi
# downloaadd : downloaadd
# digunakanklu : digunakanklu
# bapuk : bapuk
# awalawal : awalawal
# sio : sio
# payaaaahh : payaaaahh
# bercyandaaaa : bercyandaaaa
# bercyandaaa : bercyandaaa
# ejaan : eja
# ordertadinya : ordertadinya
# ditaiwan : ditaiwan
# geregetan : gereget
# terdetekssi : terdetekssi
# alamatnyaerror : alamatnyaerror
# nihsaya : nihsaya
# nyabenerin : nyabenerin
# bisaaja : bisaaja
# ngelagnya : ngelagnya
# ngecrashnya : ngecrashnya
# anyinggggg : anyinggggg
# internetnya : internetnya
# keputus : putus
# kontoi : kontoi
# bod : bod
# bangsayt : bangsayt
# dipersusah : susah
# gwe : gwe
# cantumin : cantumin
# mendunghujan : mendunghujan
# ngeheng : ngeheng
# anehudah : anehudah
# ditemukansudah : ditemukansudah
# dipeta : peta
# lokasinyaaneh : lokasinyaaneh
# manaaaaa : manaaaaa
# levelsusah : levelsusah
# llater : llater
# bandara : bandara
# nyakocage : nyakocage
# cepatcepat : cepatcepat
# ole : ole
# telponin : telponin
# sibukbapaklu : sibukbapaklu
# kedetek : kedetek
# graha : graha
# sibukpadahal : sibukpadahal
# klinik : klinik
# dpake : dpake
# bawaan : bawa
# permatadbs : permatadbs
# merantau : rantau
# benget : benget
# respect : respect
# sepii : sepi
# deposit : deposit
# dikeluarkan : keluar
# dihilangin : dihilangin
# nicee : nicee
# tugas : tugas
# greats : greats
# haripadahal : haripadahal
# ...
# mbayarkan : mbayarkan
# parkirtidak : parkirtidak
# anaknya : anak
# serah : serah
# gojekgotix : gojekgotix
# bangsad : bangsad
# gaaada : gaaada
# chatrine : chatrine
# fitua : fitua
# event : event
# kejutan : kejut
# baiksering : baiksering
# kadal : kadal
# biaaaaadaab : biaaaaadaab
# resti : resti
# ssangat : ssangat
# konco : konco
# dewe : dewe
# ngatasi : ngatasi
# sayembara : sayembara
# penjemputandriver : penjemputandriver
# maren : maren
# ket : ket
# ngangguan : ngangguan
# bingitlahh : bingitlahh
# ampasz : ampasz
# aplikasigkguna : aplikasigkguna
# wallet : wallet
# war : war
# nypdhl : nypdhl
# jauhaneh : jauhaneh
# lokasinyanhanya : lokasinyanhanya
# dikategorikan : kategori
# pokokknnya : pokokknnya
# hutuh : hutuh
# cra : cra
# ngatasinya : ngatasinya
# kerjae : kerjae
# gojekkkkkk : gojekkkkkk
# mostly : mostly
# terbaiklah : baik
# raawrrr : raawrrr
# berterimakasih : berterimakasih
# acuhkan : acuh
# gandoz : gandoz
# yaaampun : yaaampun
# diangkut : angkut
# ttepa : ttepa
# totok : totok
# prajarta : prajarta
# nopol : nopol
# norek : norek
# mudh : mudh
# mntep : mntep
# didasarkan : dasar
# notabennya : notabennya
# cenderung : cenderung
# perbanyakk : perbanyakk
# titip : titip
# kebalik : balik
# ketempatnya : tempat
# bgtdiskon : bgtdiskon
# donkmantapp : donkmantapp
# dekatkasian : dekatkasian
# ntapss : ntapss
# tanggep : tanggep
# errordan : errordan
# banak : banak
# track : track
# seramai : serama
# bubar : bubar
# alamattitik : alamattitik
# lokasitidak : lokasitidak
# sebelahgrxb : sebelahgrxb
# penghitaman : hitam
# ramaikan : ramai
# cgv : cgv
# enakk : enakk
# yoitubeh : yoitubeh
# tepepon : tepepon
# faq : faq
# gowenload : gowenload
# gondangdia : gondangdia
# pencocokan : cocok
# berjaga : jaga
# pengaruh : pengaruh
# bagussopantepat : bagussopantepat
# sdng : sdng
# aplikasiy : aplikasiy
# ain : ain
# sebelumy : sebelumy
# gapaylater : gapaylater
# disetujui : tuju
# digit : digit
# waktuin : waktuin
# kebeli : kebel
# mampirmakanan : mampirmakanan
# mekar : mekar
# kerjakalau : kerjakalau
# maaib : maaib
# aaya : aaya
# sebulanan : bulan
# telatbahkan : telatbahkan
# gojektapi : gojektapi
# sangsut : sangsut
# driverbeda : driverbeda
# sebelahtolong : sebelahtolong
# tolakjelek : tolakjelek
# mengecewakanudah : mengecewakanudah
# lgkp : lgkp
# pesak : pesak
# suranta : suranta
# diarahinnya : diarahinnya
# menjing : menjing
# bettuull : bettuull
# banking : banking
# mpe : mpe
# win : win
# domisili : domisili
# sayakarena : sayakarena
# jossssss : jossssss
# yhu : yhu
# temposebelumnya : temposebelumnya
# sajaayok : sajaayok
# ekssitensimuterima : ekssitensimuterima
# sayasalam : sayasalam
# diitungnya : diitungnya
# tamak : tamak
# najisin : najisin
# kelokasi : lokasi
# serpis : serpis
# perfomanya : perfomanya
# kenyataan : nyata
# seaman : aman
# customore : customore
# bus : bus
# gobloggg : gobloggg
# menggunkan : gun
# penglaman : lam
# ordran : ordran
# gofoodgak : gofoodgak
# menyelsaikan : menyelsaikan
# strukpadahal : strukpadahal
# jngankn : jngankn
# bisadan : bisadan
# susai : susai
# komplan : komplan
# driveseolah : driveseolah
# dicobaain : dicobaain
# paylayter : paylayter
# lee : lee
# chawnima : chawnima
# cipili : cipili
# pham : pham
# pheii : pheii
# gudd : gudd
# prosenya : prosenya
# owner : owner
# kiamat : kiamat
# robbal : robbal
# alamin : alamin
# taric : taric
# hmpr : hmpr
# hilangthanks : hilangthanks
# baikemcari : baikemcari
# xpress : xpress
# dapatmap : dapatmap
# akuratdan : akuratdan
# aplikasingeloo : aplikasingeloo
# hlm : hlm
# ngepasin : ngepasin
# diamond : diamond
# tokoknya : tokok
# diupgade : diupgade
# gojekmasa : gojekmasa
# yahud : yahud
# pesenana : pesenana
# lamaaaaaaa : lamaaaaaaa
# meribetkan : meribetkan
# dounlod : dounlod
# penaanganan : penaanganan
# nawarinklu : nawarinklu
# muludi : muludi
# terusdiisi : terusdiisi
# tolakjgn : tolakjgn
# tolakparah : tolakparah
# dirangkap : rangkap
# rangkap : rangkap
# kapitalisme : kapitalisme
# henk : henk
# aestetik : aestetik
# karawang : karawang
# sampaisampai : sampaisampai
# digabunggabungin : digabunggabungin
# ngeruk : ngeruk
# promonyaaaaa : promonyaaaaa
# iniaplagi : iniaplagi
# belon : belon
# suek : suek
# bertranportasi : bertranportasi
# jua : jua
# berwawasan : wawas
# fositif : fositif
# akunku : akun
# costomer : costomer
# letak : letak
# meja : meja
# nelponin : nelponin
# syukur : syukur
# cmna : cmna
# softexdan : softexdan
# indomie : indomie
# diretas : retas
# pondok : pondok
# cekidot : cekidot
# canva : canva
# lift : lift
# apartemen : apartemen
# oopsada : oopsada
# wae : wae
# rudet : rudet
# warteg : warteg
# dimolorin : dimolorin
# jon : jon
# stabilin : stabilin
# appl : appl
# gabjsa : gabjsa
# mrmbagongkan : mrmbagongkan
# tertangapi : tangap
# layangan : layang
# promonyabnyk : promonyabnyk
# jain : jain
# bola : bola
# dog : dog
# kaput : kaput
# daptar : daptar
# spinjem : spinjem
# bangetpokok : bangetpokok
# dinegeri : negeri
# mahalklau : mahalklau
# senantiasa : senantiasa
# maxsimal : maxsimal
# kilogram : kilogram
# inventaris : inventaris
# gaspol : gaspol
# alhamdulillahsiip : alhamdulillahsiip
# dipakaipadahal : dipakaipadahal
# asikkkkkkk : asikkkkkkk
# berterima : terima
# lancargopaylater : lancargopaylater
# dpakek : dpakek
# ongkire : ongkire
# ongkiregila : ongkiregila
# kebtuhn : kebtuhn
# apliksi : apliksi
# goofodny : goofodny
# maantap : maantap
# lainn : lainn
# kerunah : kerunah
# kemalaman : malam
# gunanin : gunanin
# gh : gh
# mengirimi : kirim
# galau : galau
# sedirian : diri
# spylater : spylater
# ngegofood : ngegofood
# sinyaljaringan : sinyaljaringan
# yasemoga : yasemoga
# congrats : congrats
# diburu : buru
# jengkelin : jengkelin
# ngebutt : ngebutt
# songongpada : songongpada
# taiiikk : taiiikk
# serdam : serdam
# ogahan : ogah
# ganticancel : ganticancel
# ngaggur : ngaggur
# five : five
# kesabarannya : sabar
# setipis : setip
# tisu : tisu
# nihudah : nihudah
# custnya : custnya
# dituntut : tuntut
# tungu : tungu
# pangil : pangil
# rbbiaya : rbbiaya
# rbsekarang : rbsekarang
# nunggunyamakanan : nunggunyamakanan
# jamsekarang : jamsekarang
# memanfaatin : memanfaatin
# kastamerresto : kastamerresto
# providernya : providernya
# banyakkok : banyakkok
# ngelesin : ngelesin
# ux : ux
# tampilin : tampilin
# aware : aware
# pembuatan : buat
# initapi : initapi
# lamasudah : lamasudah
# drvernya : drvernya
# jampadahal : jampadahal
# luaran : luar
# ngagurmakanya : ngagurmakanya
# anyepdah : anyepdah
# kotaku : kota
# adeeeeh : adeeeeh
# sistemnyasya : sistemnyasya
# pdalah : pdalah
# terimakasihaplikasi : terimakasihaplikasi
# draiverny : draiverny
# mantbbb : mantbbb
# uphabis : uphabis
# montor : montor
# buatmbayar : buatmbayar
# gojekapa : gojekapa
# diperbaikinya : baik
# lamamenunggu : lamamenunggu
# menitsetelah : menitsetelah
# restosedangkan : restosedangkan
# sampaimending : sampaimending
# orderkeburu : orderkeburu
# staf : staf
# slu : slu
# ajatuh : ajatuh
# manaaadisuruh : manaaadisuruh
# responn : responn
# lamakelamaan : lamakelamaan
# sir : sir
# dibagikan : bagi
# spert : spert
# penjajahprtama : penjajahprtama
# baxak : baxak
# penjajahnyaad : penjajahnyaad
# lainaneh : lainaneh
# verifikasinys : verifikasinys
# lapak : lapak
# diperbesar : besar
# perbesar : besar
# gope : gope
# coinnya : coinnya
# gofoodgocardan : gofoodgocardan
# palembang : palembang
# perhatiannya : perhati
# indonesiaaamiiin : indonesiaaamiiin
# kadangkadang : kadangkadang
# derevernya : derevernya
# sabaran : sabar
# penyabar : sabar
# debi : debi
# sutopo : sutopo
# sbrn : sbrn
# direct : direct
# samain : samain
# tautan : taut
# lamanoh : lamanoh
# pindqh : pindqh
# drivermendingan : drivermendingan
# konsumenya : konsumenya
# jidatnya : jidat
# xpxxj : xpxxj
# semakun : semakun
# mhal : mhal
# dadah : dadah
# apliksai : apliksai
# andamembeli : andamembeli
# rumahuntk : rumahuntk
# foodnysemua : foodnysemua
# jdimudah : jdimudah
# mewadahi : wadah
# programmernya : programmernya
# ongking : ongking
# amboradol : amboradol
# moon : moon
# masukbikin : masukbikin
# tipispokonya : tipispokonya
# sayatetima : sayatetima
# gunaka : gunaka
# bongak : bongak
# peler : peler
# babang : babang
# twitter : twitter
# burubagusan : burubagusan
# emergency : emergency
# ferrari : ferrari
# nth : nth
# merasukimu : rasuk
# ambilmending : ambilmending
# suck : suck
# funsinya : funsinya
# kecacatan : cacat
# terdahalu : terdahalu
# brati : brati
# berujung : ujung
# apknlain : apknlain
# recommend : recommend
# mngecewakan : mngecewakan
# cangkupan : cangkup
# pencariannya : cari
# lom : lom
# garut : garut
# mantulmantap : mantulmantap
# biaasa : biaasa
# uaddeemmm : uaddeemmm
# disinikarna : disinikarna
# primitif : primitif
# wadidaw : wadidaw
# goshopp : goshopp
# ningguin : ningguin
# karen : karen
# konsomen : konsomen
# bernanfaat : bernanfaat
# mantapks : mantapks
# mles : mles
# mahalmahal : mahalmahal
# jakrta : jakrta
# nalumsari : nalumsari
# mts : mts
# balekambang : balekambang
# abng : abng
# sbar : sbar
# alamt : alamt
# sempurnakn : sempurnakn
# gliran : gliran
# jadwalnya : jadwal
# updateapanya : updateapanya
# goodmending : goodmending
# lahirnya : lahir
# menyadari : sadar
# dasarnya : dasar
# ulur : ulur
# lambung : lambung
# berbelat : belat
# belit : belit
# menjengkelkan : jengkel
# mobilitasi : mobilitas
# driverpelayanan : driverpelayanan
# adem : adem
# dlmnya : dlmnya
# berbohong : bohong
# sekarangresto : sekarangresto
# xpdegv : xpdegv
# etol : etol
# usahankan : usahankan
# gojekjadi : gojekjadi
# manapromonya : manapromonya
# kubisa : bisa
# buatku : buat
# jigong : jigong
# packing : packing
# bangs : bangs
# gasspol : gasspol
# terisi : isi
# najisss : najisss
# mantapa : mantapa
# jammapk : jammapk
# feenya : feenya
# atopun : ato
# tolooong : tolooong
# beneeer : beneeer
# erro : erro
# lohblm : lohblm
# lawas : lawas
# dinaikinnya : dinaikinnya
# selisihnya : selisih
# juossss : juossss
# gopayater : gopayater
# bayarseki : bayarseki
# diblokirpadahal : diblokirpadahal
# ngoperasiin : ngoperasiin
# isep : isep
# kriget : kriget
# nyaaplikasi : nyaaplikasi
# sekargdriver : sekargdriver
# belangsakin : belangsakin
# bermasalahdi : bermasalahdi
# adahapus : adahapus
# jempolan : jempol
# syksus : syksus
# dipakr : dipakr
# limetnyee : limetnyee
# gojjek : gojjek
# fair : fair
# akunx : akunx
# orglain : orglain
# ramekan : ramekan
# mengcancel : mengcancel
# boycott : boycott
# enek : enek
# dimanake : dimanake
# gur : gur
# seblak : seblak
# huruf : huruf
# cukupmemuaskan : cukupmemuaskan
# bagusudah : bagusudah
# ajagw : ajagw
# biaa : biaa
# letternya : letternya
# bisaselalu : bisaselalu
# memanggil : panggil
# teraman : ram
# jengekelin : jengekelin
# permaimkan : permaimkan
# duluuuu : duluuuu
# digunakanpdhal : digunakanpdhal
# bisaharus : bisaharus
# tambain : tambain
# mangtabss : mangtabss
# tunggunya : tunggu
# yaknp : yaknp
# dicatet : dicatet
# petugas : tugas
# bersistem : sistem
# biadaaab : biadaaab
# sisaan : sisa
# lammaaaaaaaaa : lammaaaaaaaaa
# faith : faith
# muraaaah : muraaaah
# makasihhh : makasihhh
# nemenin : nemenin
# bolelah : bolelah
# banyakbanyaksekarang : banyakbanyaksekarang
# resahnunggu : resahnunggu
# lhohati : lhohati
# gopaylaternyaprogram : gopaylaternyaprogram
# bagusbunganya : bagusbunganya
# perbulandan : perbulandan
# pemakaiannyatapi : pemakaiannyatapi
# inibunganya : inibunganya
# transaksijadi : transaksijadi
# bunganyaya : bunganyaya
# keciljadi : keciljadi
# kaarya : kaarya
# pijaman : pijaman
# goyleter : goyleter
# haya : haya
# pemanis : man
# pendanaan : dana
# oketebel : oketebel
# putusin : putusin
# yaaaaaaaaaaa : yaaaaaaaaaaa
# bissmilah : bissmilah
# mintaminta : mintaminta
# foot : foot
# rendahan : rendah
# petingginya : petinggi
# perih : perih
# nyabaik : nyabaik
# ndakm : ndakm
# laparnya : lapar
# memperbaikin : memperbaikin
# bimtang : bimtang
# kolab : kolab
# koontol : koontol
# aktf : aktf
# inj : inj
# jawabanygbenar : jawabanygbenar
# berbicarabayar : berbicarabayar
# masukpenanganannya : masukpenanganannya
# leletlemot : leletlemot
# teelalu : teelalu
# driverrrr : driverrrr
# gojekmsh : gojekmsh
# pakrir : pakrir
# gofoodpadahal : gofoodpadahal
# nyasedangkan : nyasedangkan
# bantuanlebihan : bantuanlebihan
# parkirsebaik : parkirsebaik
# planktanda : planktanda
# jasah : jasah
# onlinefood : onlinefood
# gofoodgrabfoodmaximdll : gofoodgrabfoodmaximdll
# geratiskansupaya : geratiskansupaya
# onliefood : onliefood
# pembayara : pembayara
# ramnya : ram
# perkecil : kecil
# responmohon : responmohon
# nmor : nmor
# teoat : teoat
# bagusssxxaxaa : bagusssxxaxaa
# tqpi : tqpi
# trqnsaksi : trqnsaksi
# hduhhhhh : hduhhhhh
# voicer : voicer
# bngst : bngst
# mksudnya : mksudnya
# jwaban : jwaban
# mahalsy : mahalsy
# dlltp : dlltp
# unisntal : unisntal
# propinsi : propinsi
# plan : plan
# budgeting : budgeting
# wew : wew
# performance : performance
# touch : touch
# menyusahkaan : menyusahkaan
# dengaan : dengaan
# koo : koo
# mematahui : mematahui
# berwajib : wajib
# berwinang : wang
# tersebutterima : tersebutterima
# menyertakan : serta
# merchat : merchat
# sok tau : sok tau
# ibet : ibet
# traking : traking
# sekses : sekses
# lebay : lebay
# iklanin : iklanin
# gajelaspesenan : gajelaspesenan
# driverpas : driverpas
# gobl : gobl
# gakudah : gakudah
# benerpesendapet : benerpesendapet
# orderselesai : orderselesai
# peringan : pering
# oxx : oxx
# berubahubah : berubahubah
# terkhusus : khusus
# bergaransi : garansi
# dikembalikangood : dikembalikangood
# berpakaian : pakai
# bajujaket : bajujaket
# identitassy : identitassy
# gojekdg : gojekdg
# sytrm : sytrm
# khususny : khususny
# bermasalahternyata : bermasalahternyata
# kesalahanya : kesalahanya
# gojeknyatolong : gojeknyatolong
# biasasekarang : biasasekarang
# mahallama : mahallama
# meong : meong
# foodkalian : foodkalian
# rasakan : rasa
# hematdah : hematdah
# lamadriver : lamadriver
# palkirga : palkirga
# pulatapi : pulatapi
# gagalrusakdan : gagalrusakdan
# dilindungi : lindung
# hematmending : hematmending
# pindahatau : pindahatau
# laintolol : laintolol
# untungan : untung
# figur : figur
# bermanfaatdi : bermanfaatdi
# kaumkaum : kaumkaum
# mengecewakanoder : mengecewakanoder
# dreverdrever : dreverdrever
# alhamdulillahcepat : alhamdulillahcepat
# sesimpelseringan : sesimpelseringan
# energi : energi
# terbantukan : bantu
# apky : apky
# safety : safety
# ditanggapin : ditanggapin
# mengkonfirmasi : konfirmasi
# adaiin : adaiin
# setorannya : setor
# reg : reg
# penganiayaan : aniaya
# budeg : budeg
# ngiklan : ngiklan
# disatukan : satu
# enough : enough
# consumen : consumen
# laterr : laterr
# awasi : awas
# penandaan : tanda
# carinya : cari
# sopanistimewa : sopanistimewa
# aturannya : atur
# madalah : mada
# yajadi : yajadi
# trusbiasanykn : trusbiasanykn
# berhasilini : berhasilini
# layarnya : layar
# suee : suee
# mt : mt
# sslekarang : sslekarang
# dipepetin : tin
# truck : truck
# container : container
# peti : peti
# kemas : kemas
# reviewreport : reviewreport
# pembyran : pembyran
# perbaikn : perbaikn
# siatempdahl : siatempdahl
# banyakinn : banyakinn
# lovee : lovee
# ujandriver : ujandriver
# bengong : bengong
# hm : hm
# gopinjamsetelah : gopinjamsetelah
# dipakaikemudian : dipakaikemudian
# terushehehe : terushehehe
# tayang : tayang
# dipaketgl : dipaketgl
# jttapi : jttapi
# dipakeheheheaplikasi : dipakeheheheaplikasi
# bosokiki : bosokiki
# endapan : endap
# hadeeeh : hadeeeh
# mantaflah : mantaflah
# message : message
# jni : jni
# qrisnada : qrisnada
# drivernyapadahal : drivernyapadahal
# ownernya : ownernya
# csl : csl
# berkala : kala
# cangih : cangih
# paras : paras
# seriwil : seriwil
# busukgak : busukgak
# sesakit : sakit
# sakitnya : sakit
# huff : huff
# menjelekkan : jelek
# prores : prores
# tepatjooos : tepatjooos
# gandoss : gandoss
# pnh : pnh
# bermslh : bermslh
# penyelesain : penyelesain
# pusiiiiing : pusiiiiing
# hlj : hlj
# uhgy : uhgy
# inipesanan : inipesanan
# banyakkita : banyakkita
# lagiminta : lagiminta
# kenyaman : kenyam
# msukpdahal : msukpdahal
# bayara : bayara
# coca : coca
# cola : cola
# botol : botol
# gaabisa : gaabisa
# lebi : lebi
# ngotot : ngotot
# diponsel : diponsel
# kendaraanojek : kendaraanojek
# navigasi : navigasi
# karnakan : karnakan
# ech : ech
# peringatanya : peringatanya
# gilee : gilee
# setiapku : tiap
# yaharus : yaharus
# driverpersaingan : driverpersaingan
# kebijakankalo : kebijakankalo
# dicompare : dicompare
# nv : nv
# gos : gos
# jmmlk : jmmlk
# mmmmiikkki : mmmmiikkki
# rtvvookn : rtvvookn
# cvvvv : cvvvv
# vv : vv
# durasinya : durasi
# ngacooooo : ngacooooo
# laahh : laahh
# asw : asw
# wok : wok
# sekitarnyakebanyakkan : sekitarnyakebanyakkan
# gojekseperti : gojekseperti
# didesa : desa
# siluman : siluman
# pabuarandan : pabuarandan
# hambaro : hambaro
# subangtolong : subangtolong
# pegemudi : gudi
# mamkatu : mamkatu
# arateng : arateng
# bacukaek : bacukaek
# karis : karis
# amrgamitwan : amrgamitwan
# niamkarapa : niamkarapa
# bera : bera
# selanjaru : selanjaru
# duamspa : duamspa
# fukamapskm : fukamapskm
# mdatu : mdatu
# busikavetu : busikavetu
# furahsu : furahsu
# gangatukasi : gangatukasi
# bayau : bayau
# duagi : duagi
# ankarupea : ankarupea
# huatabemkay : huatabemkay
# mytsel : mytsel
# myim : myim
# ngusir : ngusir
# diskonnye : diskonnye
# hem : hem
# nb : nb
# tololll : tololll
# pemikiran : pikir
# sjaa : sjaa
# nihkecewa : nihkecewa
# Pandas Apply:   0%|          | 0/19094 [00:00<?, ?it/s]

# %%
df.to_csv("data_cleangojek.csv", index = False)

# %% [markdown]
# <h1> Data clean

# %% [markdown]
# **Import Library**

# %%
import pandas as pd
import numpy as np

#plot Grafik
import matplotlib.pyplot as plt
import missingno as msno

# %%
df = pd.read_csv("data_cleangojek.csv")
display(df)
# Out:
#                        userName  score                   at  \
# 0          Pijat sehat mm sindy      1  2024-02-05 12:03:59
# 1                        Ayu Sr      5  2024-02-05 11:52:50
# 2                  Dilla Almira      1  2024-02-05 11:46:50
# 3                  Nur Solichin      1  2024-02-05 11:45:54
# 4            aming Rivoallansah      1  2024-02-05 11:41:23
# ...                         ...    ...                  ...
# 19089              Andre Dinand      5  2023-11-20 16:33:20
# 19090              avian muslim      5  2023-11-20 16:30:00
# 19091            Andro Sulistio      5  2023-11-20 16:28:26
# 19092  Uswatun “Chubby” Hasanah      2  2023-11-20 16:17:23
# 19093            Dedy Wijayanto      1  2023-11-20 16:08:16
#
#                                                  content    label  \
# 0      sangat burukorder yg jemput blum ada gopay nya...  negatif
# 1      transportasi dan pesan makanan nya murah banya...  positif
# 2      makin di update makin ga jelas ga bisa kirim f...  negatif
# 3                           maps nya selalu salah tujuan  negatif
# 4      pembayaran pulsa gagal ada aktivitas mencuriga...  negatif
# ...                                                  ...      ...
# 19089                                  karya anak bangsa  positif
# 19090                                             mantap  positif
# 19091                                               good  positif
# 19092  lagi ada gangguan ap gimana siihhh sekarang  p...  negatif
# 19093  kenapa gopay later saya tidak bisa dipakai pad...  negatif
#
#                                         content_tokenize  \
# 0      ['sangat', 'burukorder', 'yg', 'jemput', 'blum...
# 1      ['transportasi', 'dan', 'pesan', 'makanan', 'n...
# 2      ['makin', 'di', 'update', 'makin', 'ga', 'jela...
# 3           ['maps', 'nya', 'selalu', 'salah', 'tujuan']
# 4      ['pembayaran', 'pulsa', 'gagal', 'ada', 'aktiv...
# ...                                                  ...
# 19089                        ['karya', 'anak', 'bangsa']
# 19090                                         ['mantap']
# 19091                                           ['good']
# 19092  ['lagi', 'ada', 'gangguan', 'ap', 'gimana', 's...
# 19093  ['kenapa', 'gopay', 'later', 'saya', 'tidak', ...
#
#                                       content_normalized  \
# 0      ['sangat', 'burukorder', 'yang', 'jemput', 'be...
# 1      ['transportasi', 'dan', 'pesan', 'makanan', 'n...
# 2      ['makin', 'di', 'update', 'makin', 'enggak', '...
# 3           ['maps', 'nya', 'selalu', 'salah', 'tujuan']
# 4      ['pembayaran', 'pulsa', 'gagal', 'ada', 'aktiv...
# ...                                                  ...
# 19089                        ['karya', 'anak', 'bangsa']
# 19090                                         ['mantap']
# 19091                                           ['good']
# 19092  ['lagi', 'ada', 'gangguan', 'apa', 'bagaimana'...
# 19093  ['kenapa', 'gopay', 'later', 'saya', 'tidak', ...
#
#                                     content_stop_removed  \
# 0      ['burukorder', 'jemput', 'gopay', 'nya', 'hila...
# 1      ['transportasi', 'pesan', 'makanan', 'nya', 'm...
# 2      ['update', 'kirim', 'foto', 'driver', 'galeri'...
# 3                     ['maps', 'nya', 'salah', 'tujuan']
# 4      ['pembayaran', 'pulsa', 'gagal', 'aktivitas', ...
# ...                                                  ...
# 19089                        ['karya', 'anak', 'bangsa']
# 19090                                         ['mantap']
# 19091                                           ['good']
# 19092  ['gangguan', 'sih', 'pas', 'upgred', 'nihkecewa']
# 19093  ['gopay', 'later', 'dipakai', 'diandalkan', 't...
#
#                                          content_Stemmed
# 0      ['burukorder', 'jemput', 'gopay', 'nya', 'hila...
# 1      ['transportasi', 'pesan', 'makan', 'nya', 'mur...
# 2      ['update', 'kirim', 'foto', 'driver', 'galeri'...
# 3                       ['maps', 'nya', 'salah', 'tuju']
# 4      ['bayar', 'pulsa', 'gagal', 'aktivitas', 'curi...
# ...                                                  ...
# 19089                        ['karya', 'anak', 'bangsa']
# 19090                                         ['mantap']
# 19091                                           ['good']
# 19092    ['ganggu', 'sih', 'pas', 'upgred', 'nihkecewa']
# 19093  ['gopay', 'later', 'pakai', 'andal', 'terang',...
#
# [19094 rows x 9 columns]

# %%
df["label"].value_counts()
# Out:
# positif    11921
# negatif     7173
# Name: label, dtype: int64

# %%
def sentimen(data:int):
  if data > 0:
    return "positif"
  elif data < 0:
    return "negatif"
  else:
    return "netral"

# %%
df_ = pd.read_csv('data_cleangojek.csv')

# Plot the histogram
sns.histplot(data=df_, x="label")
# Out:
# <Axes: xlabel='label', ylabel='Count'>

# %% [markdown]
# <h1> Oversampling

# %%
from sklearn.utils import resample
df_majority = df[(df['label']=="positif")]
df_minority = df[(df['label']=="negatif")]

df_minority_upsampled = resample(df_minority,
                                 replace=True,    # sample with replacement
                                 n_samples=12914, # to match majority class
                                 random_state=42)  # reproducible results

df_upsampled = pd.concat([df_minority_upsampled, df_majority])

# %%
df_upsampled["label"].value_counts()
# Out:
# negatif    12914
# positif    11921
# Name: label, dtype: int64

# %% [markdown]
# <h1> Transformation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
tfidf_stemmed = vectorizer.fit_transform(df['content_Stemmed'])
dense= tfidf_stemmed.toarray()

# %% [markdown]
# <h1> Text Mining
#
# **Data Splitting**

# %%
from sklearn.model_selection import train_test_split

X_train1, X_test1, Y_train1, Y_test1 = train_test_split(dense, df['label'], test_size = 0.1, random_state= 42)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(X_train1,Y_train1)

# %% [markdown]
# <h1> Evaluasi

# %%
from sklearn.metrics import confusion_matrix

evaluasi = gnb.predict(X_test1)
print(confusion_matrix(Y_test1, evaluasi))
# Out:
# [[ 301  412]
#  [  65 1132]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test1, evaluasi))
# Out:
# 0.750261780104712

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test1, evaluasi))
# Out:
#               precision    recall  f1-score   support
#
#      negatif       0.82      0.42      0.56       713
#      positif       0.73      0.95      0.83      1197
#
#     accuracy                           0.75      1910
#    macro avg       0.78      0.68      0.69      1910
# weighted avg       0.77      0.75      0.73      1910

# %%
import matplotlib.pyplot as plt
from jcopml.plot import plot_confusion_matrix


plot_confusion_matrix(X_train1, Y_train1, X_test1, Y_test1, gnb)
plt.show()

# %%
from sklearn import metrics

confusion_matrix = metrics.confusion_matrix(Y_test1, evaluasi)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()
